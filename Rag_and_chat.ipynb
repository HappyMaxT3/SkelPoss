# %%
from langchain_gigachat import GigaChat
import os
import torch
from langchain.document_loaders import TextLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import Chroma
from langchain_groq import ChatGroq
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate
from dotenv import load_dotenv
import pandas as pd
import re
from typing import List
from sentence_transformers import CrossEncoder
from langchain_core.output_parsers import StrOutputParser

# Проверяем доступность GPU
print(f"CUDA доступен: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    device = "cuda"
else:
    print("GPU не доступен, используем CPU")
    device = "cpu"

# Настройка GROQ API ключа
GROQ_API_KEY = "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"
if not GROQ_API_KEY:
    raise ValueError("GROQ_API_KEY не найден. Убедитесь, что он указан в .env файле")

# Путь к директории с текстовыми документами и векторному хранилищу
DOCUMENTS_DIR = "/content/data"
VECTOR_DB_PATH = "/content/drive/MyDrive/chroma_db_1"
types = set()
def load_documents(directory):
    """Загружает все текстовые документы из указанной директории и добавляет имя файла в метаданные"""
    documents = []
    for filename in os.listdir(directory):
        if filename.endswith('.txt'):
            file_path = os.path.join(directory, filename)
            try:
                loader = TextLoader(file_path)
                docs = loader.load()

                # Добавляем имя файла в метаданные
                for doc in docs:
                    metadatas = doc.page_content.split('\n')[0:3]
                    metadatas = [x.split(':',1)[1].lstrip() for x in metadatas]
                    doc.metadata["Источник"] = metadatas[0]
                    doc.metadata["Тип"] = metadatas[1]
                    doc.metadata["Модель"] = metadatas[2]
                    types.add(metadatas[1])
                    print(doc.metadata)
                documents.extend(docs)
            except Exception as e:
                print(f"Ошибка при загрузке {filename}: {str(e)}")
    return documents

def create_vectorstore(documents):
    """Создает и сохраняет векторное хранилище из документов, используя GPU"""
    # Разбиваем документы на чанки
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=30,
        chunk_overlap=0,
        length_function=len,
        separators=[';',"\n"]
    )
    split_docs = text_splitter.split_documents(documents)

    # Создаем эмбеддинги с использованием GPU
    model_kwargs = {'device': device}
    encode_kwargs = {'device': device, 'batch_size': 128}  # Увеличиваем batch_size для GPU

    embeddings = HuggingFaceEmbeddings(
        model_name='intfloat/multilingual-e5-large',
        model_kwargs=model_kwargs,
        encode_kwargs=encode_kwargs
    )

    print(f"Создание векторного хранилища на {device}...")
    # Создаем векторное хранилище
    vectorstore = Chroma.from_documents(
        documents=split_docs,
        embedding=embeddings,
        persist_directory=VECTOR_DB_PATH
    )

    # Сохраняем хранилище на диск
    vectorstore.persist()
    print(f"Векторное хранилище создано и сохранено в {VECTOR_DB_PATH}")

    return vectorstore

def load_vectorstore():
    """Загружает существующее векторное хранилище"""
    # Настраиваем модель эмбеддингов для использования GPU
    model_kwargs = {'device': device}
    encode_kwargs = {'device': device, 'batch_size': 32}

    embeddings = HuggingFaceEmbeddings(
        model_name='intfloat/multilingual-e5-large',
        model_kwargs=model_kwargs,
        encode_kwargs=encode_kwargs
    )

    # Загружаем существующее хранилище
    vectorstore = Chroma(
        persist_directory=VECTOR_DB_PATH,
        embedding_function=embeddings
    )

    print(f"Векторное хранилище загружено из {VECTOR_DB_PATH}")
    return vectorstore

# Остальной код остается без изменений
def setup_rag_system():
    """Настраивает RAG систему, загружая или создавая векторное хранилище"""
    # Проверяем, существует ли уже векторное хранилище
    if os.path.exists(VECTOR_DB_PATH) and os.listdir(VECTOR_DB_PATH):
        # Если хранилище существует, загружаем его
        vectorstore = load_vectorstore()
        load_documents(DOCUMENTS_DIR)
    else:
        # Если хранилища нет, создаем новое
        print("Векторное хранилище не найдено. Создаем новое...")
        documents = load_documents(DOCUMENTS_DIR)
        if not documents:
            raise ValueError("Не удалось загрузить ни одного документа!")
        vectorstore = create_vectorstore(documents)

    # Настраиваем GROQ LLM
    llm = ChatGroq(
        groq_api_key=GROQ_API_KEY,
        model_name="llama3-70b-8192",
        temperature=0.3,
        max_tokens=1400,
    )

    return vectorstore, llm

# Остальной код без изменений...


try:
    # Настраиваем RAG систему (загружаем существующее хранилище или создаем новое)
    print("Настройка RAG системы...")
    vectorstore, llm = setup_rag_system()


except Exception as e:
    print(f"Произошла ошибка: {str(e)}")

# Если нужно обновить хранилище (например, при добавлении новых документов):
# update_vectorstore()



print(types)
# Out:
# CUDA доступен: False
# GPU не доступен, используем CPU
# Настройка RAG системы...
# Векторное хранилище загружено из /content/drive/MyDrive/chroma_db_1
# {'source': '/content/data/mini-pec-dexp-vn-3800-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/78b655e9fa0ded20/mini-pec-dexp-vn-3800-cernyj/characteristics/', 'Тип': 'мини-печь', 'Модель': 'DEXP VN-3800'}
# {'source': '/content/data/masorubka-elektriceskaa-redmond-rmg-1203-8-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/a907340142b03120/masorubka-elektriceskaa-redmond-rmg-1203-8-belyj/characteristics/', 'Тип': 'мясорубка электрическая', 'Модель': 'Redmond RMG-1203-8'}
# {'source': '/content/data/multivarka-polaris-pmc-0573ad-serebristyj.txt', 'Источник': 'https://www.dns-shop.ru/product/72ca334cd5371b80/multivarka-polaris-pmc-0573ad-serebristyj/characteristics/', 'Тип': 'мультиварка', 'Модель': 'Polaris PMC 0573AD'}
# {'source': '/content/data/holodilnik-kompaktnyj--birusa-70-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/04160f86c2d33330/holodilnik-kompaktnyj--birusa-70-belyj/characteristics/', 'Тип': 'холодильник компактный', 'Модель': 'Бирюса 70'}
# {'source': '/content/data/pylesos-thomas--aquatic-onyx-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/70458d867ef3d582/pylesos-thomas--aquatic-onyx-cernyj/characteristics/', 'Тип': 'пылесос', 'Модель': 'Thomas  Aquatic Onyx'}
# {'source': '/content/data/mini-pec-kraft-kfc-mo-200-hw-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/878b1bf53248432d/mini-pec-kraft-kfc-mo-200-hw-belyj/characteristics/', 'Тип': 'мини-печь', 'Модель': 'Kraft KFC-MO 200 HW'}
# {'source': '/content/data/kombinirovannaa-plita-gefest-pge-6102-01-0198-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/cd01c454cc2960c5/kombinirovannaa-plita-gefest-pge-6102-01-0198-belyj/characteristics/', 'Тип': 'плита комбинированная', 'Модель': 'Gefest ПГЭ 6102-01 0198'}
# {'source': '/content/data/gazovaa-plita-gefest-3200-08-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/01f285c2adb23361/gazovaa-plita-gefest-3200-08-belyj/characteristics/', 'Тип': 'газовая плита', 'Модель': 'Gefest 3200-08'}
# {'source': '/content/data/masorubka-elektriceskaa-moulinex-hv8-pro-me686832-seryj.txt', 'Источник': 'https://www.dns-shop.ru/product/d6a14ff7d9d23330/masorubka-elektriceskaa-moulinex-hv8-pro-me686832-seryj/characteristics/', 'Тип': 'мясорубка электрическая', 'Модель': 'Moulinex HV8 Pro ME686832'}
# {'source': '/content/data/pylesos-bosch-bgc21x300-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/bcf579886718ed20/pylesos-bosch-bgc21x300-cernyj/characteristics/', 'Тип': 'пылесос', 'Модель': 'Bosch BGC21X300'}
# {'source': '/content/data/masorubka-elektriceskaa-moulinex-hv7-pro-me556810-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/60b2672a3abb2ff2/masorubka-elektriceskaa-moulinex-hv7-pro-me556810-cernyj/characteristics/', 'Тип': 'мясорубка электрическая', 'Модель': 'Moulinex HV7 Pro ME556810'}
# {'source': '/content/data/kondicioner-nastennyj-split-sistema-tcl-eli-inv-12-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/c86b27b25844ed20/kondicioner-nastennyj-split-sistema-tcl-eli-inv-12-belyj/characteristics/', 'Тип': 'кондиционер', 'Модель': 'TCL ELI INV 12'}
# {'source': '/content/data/kondicioner-nastennyj-split-sistema-electrolux-eacsi-12hatn3_21y-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/8e7079ef9b742ff4/kondicioner-nastennyj-split-sistema-electrolux-eacsi-12hatn3_21y-belyj/characteristics/', 'Тип': 'кондиционер', 'Модель': 'Electrolux EACS/I-12HAT/N3_21Y'}
# {'source': '/content/data/mini-pec-redmond-ro-5706s-serebristyj.txt', 'Источник': 'https://www.dns-shop.ru/product/99e5c180c3513330/mini-pec-redmond-ro-5706s-serebristyj/characteristics/', 'Тип': 'мини-печь', 'Модель': 'Redmond RO-5706S'}
# {'source': '/content/data/masorubka-elektriceskaa-bosch-mfw-68640-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/2c01cdef37dfed20/masorubka-elektriceskaa-bosch-mfw-68640-cernyj/characteristics/', 'Тип': 'мясорубка электрическая', 'Модель': 'Bosch MFW 68640'}
# {'source': '/content/data/ventilator-tefal-urban-cool-vf6720f0--belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/52c96af3a3f72eb0/ventilator-tefal-urban-cool-vf6720f0--belyj/characteristics/', 'Тип': 'вентилятор', 'Модель': 'Tefal Urban Cool VF6720F0'}
# {'source': '/content/data/multivarka-redmond-skycooker-rmc-m224s-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/ca8bce51ad30867b/multivarka-redmond-skycooker-rmc-m224s-cernyj/characteristics/', 'Тип': 'мультиварка', 'Модель': 'Redmond SkyCooker RMC-M224S'}
# {'source': '/content/data/kombinirovannaa-plita-gefest-pge-5302-04-0040-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/656fb0f4d1ff4a48/kombinirovannaa-plita-gefest-pge-5302-04-0040-belyj/characteristics/', 'Тип': 'плита комбинированная', 'Модель': 'Gefest ПГЭ 5302-04 0040'}
# {'source': '/content/data/masorubka-elektriceskaa-moulinex-hv1-me111032-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/30299e04d0631b80/masorubka-elektriceskaa-moulinex-hv1-me111032-belyj/characteristics/', 'Тип': 'мясорубка электрическая', 'Модель': 'Moulinex HV1 ME111032'}
# {'source': '/content/data/ventilator-midea-fd-1520--belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/cfeba21065073330/ventilator-midea-fd-1520--belyj/characteristics/', 'Тип': 'вентилятор', 'Модель': 'Midea FD 1520'}
# {'source': '/content/data/pylesos-samsung-sc5241-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/a42f53c84d61a834/pylesos-samsung-sc5241-cernyj/characteristics/', 'Тип': 'пылесос', 'Модель': 'Samsung SC5241'}
# {'source': '/content/data/pylesos-samsung-sc18m3160vg-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/5110e8d7acb43330/pylesos-samsung-sc18m3160vg-cernyj/characteristics/', 'Тип': 'пылесос', 'Модель': 'Samsung SC18M3160VG'}
# {'source': '/content/data/masorubka-elektriceskaa-reoka-rkmg-md251-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/c25046b96317cb6e/masorubka-elektriceskaa-reoka-rkmg-md251-cernyj/characteristics/', 'Тип': 'мясорубка электрическая', 'Модель': 'Reoka RKMG-MD251'}
# {'source': '/content/data/kombinirovannaa-plita-gefest-pge-6102-01-0194-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/214276c9f16b357f/kombinirovannaa-plita-gefest-pge-6102-01-0194-cernyj/characteristics/', 'Тип': 'плита комбинированная', 'Модель': 'Gefest ПГЭ 6102-01 0194'}
# {'source': '/content/data/ventilator-tefal-essential-vf3910f0--cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/c476e0e08de93333/ventilator-tefal-essential-vf3910f0--cernyj/characteristics/', 'Тип': 'вентилятор', 'Модель': 'Tefal Еssential VF3910F0'}
# {'source': '/content/data/ventilator-brayer-br4974--cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/067b8497b0d5ed20/ventilator-brayer-br4974--cernyj/characteristics/', 'Тип': 'вентилятор', 'Модель': 'BRAYER BR4974'}
# {'source': '/content/data/pylesos-centek-ct-2529-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/caecae4eab9d3330/pylesos-centek-ct-2529-cernyj/characteristics/', 'Тип': 'пылесос', 'Модель': 'Centek CT-2529'}
# {'source': '/content/data/kondicioner-nastennyj-split-sistema-electrolux-eacsi-09hatn3_21y-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/8e7079ed9b742ff4/kondicioner-nastennyj-split-sistema-electrolux-eacsi-09hatn3_21y-belyj/characteristics/', 'Тип': 'кондиционер', 'Модель': 'Electrolux EACS/I-09HAT/N3_21Y'}
# {'source': '/content/data/ventilator-ballu-bff-907--cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/b86e0bb9e09854fd/ventilator-ballu-bff-907--cernyj/characteristics/', 'Тип': 'вентилятор', 'Модель': 'Ballu BFF-907'}
# {'source': '/content/data/pylesos-thomas-aqua-box-compact-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/e25b0c3ceb553330/pylesos-thomas-aqua-box-compact-cernyj/characteristics/', 'Тип': 'пылесос', 'Модель': 'Thomas AQUA-BOX Compact'}
# {'source': '/content/data/pylesos-bosch-bgbs2lb1-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/73b9c8784dcced20/pylesos-bosch-bgbs2lb1-cernyj/characteristics/', 'Тип': 'пылесос', 'Модель': 'Bosch BGBS2LB1'}
# {'source': '/content/data/gazovaa-plita-gefest-gs-1207-w-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/5c7ca82b54133330/gazovaa-plita-gefest-gs-1207-w-belyj/characteristics/', 'Тип': 'газовая плита', 'Модель': 'Gefest GS 1207 W'}
# {'source': '/content/data/ventilator-timberk-t-df901--belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/aee879517da22ff4/ventilator-timberk-t-df901--belyj/characteristics/', 'Тип': 'вентилятор', 'Модель': 'Timberk T-DF901'}
# {'source': '/content/data/pylesos-centek-ct-2541-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/6c11786b084bf698/pylesos-centek-ct-2541-cernyj/characteristics/', 'Тип': 'пылесос', 'Модель': 'Centek CT-2541'}
# {'source': '/content/data/pylesos-hyundai-hyv-b4995-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/a4866cee195b707c/pylesos-hyundai-hyv-b4995-cernyj/characteristics/', 'Тип': 'пылесос', 'Модель': 'Hyundai HYV-B4995'}
# {'source': '/content/data/masorubka-elektriceskaa-redmond-rmg-1216-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/9976631b52e33332/masorubka-elektriceskaa-redmond-rmg-1216-cernyj/characteristics/', 'Тип': 'мясорубка электрическая', 'Модель': 'РЕДМОНД RMG-1216'}
# {'source': '/content/data/mini-pec-dexp-vn-1000-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/95f3afa8aa8d3330/mini-pec-dexp-vn-1000-cernyj/characteristics/', 'Тип': 'мини-печь', 'Модель': 'DEXP VN-1000'}
# {'source': '/content/data/masorubka-elektriceskaa-polaris-pmg-2050-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/f5e553c947931dd2/masorubka-elektriceskaa-polaris-pmg-2050-belyj/characteristics/', 'Тип': 'мясорубка электрическая', 'Модель': 'Polaris PMG 2050'}
# {'source': '/content/data/multivarka-skorovarka-tefal-turbo-cuisine-cy753832-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/79f64a6aa6582eb0/multivarka-skorovarka-tefal-turbo-cuisine-cy753832-cernyj/characteristics/', 'Тип': 'мультиварка-скороварка', 'Модель': 'Tefal Turbo Cuisine CY753832'}
# {'source': '/content/data/multivarka-polaris-pmc-0567ad-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/31197d70af9a3332/multivarka-polaris-pmc-0567ad-cernyj/characteristics/', 'Тип': 'мультиварка', 'Модель': 'Polaris PMC 0567AD'}
# {'source': '/content/data/kombinirovannaa-plita-darina-3362-s-serebristyj.txt', 'Источник': 'https://www.dns-shop.ru/product/8514d7b7329e0ddc/kombinirovannaa-plita-darina-3362-s-serebristyj/characteristics/', 'Тип': 'плита комбинированная', 'Модель': 'DARINA 3362 S'}
# {'source': '/content/data/kombinirovannaa-plita-gorenje-gks5c70xf-seryj.txt', 'Источник': 'https://www.dns-shop.ru/product/305e52dab6aed8c4/kombinirovannaa-plita-gorenje-gks5c70xf-seryj/characteristics/', 'Тип': 'плита комбинированная', 'Модель': 'Gorenje GKS5C70XF'}
# {'source': '/content/data/pylesos-dexp-2000rb-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/cc89ef37f399ed20/pylesos-dexp-2000rb-cernyj/characteristics/', 'Тип': 'пылесос', 'Модель': 'DEXP 2000RB'}
# {'source': '/content/data/kondicioner-nastennyj-split-sistema-iffalcon-f1-inv-07-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/9cd01c7f583aed20/kondicioner-nastennyj-split-sistema-iffalcon-f1-inv-07-belyj/characteristics/', 'Тип': 'кондиционер', 'Модель': 'iFFALCON F1 INV 07'}
# {'source': '/content/data/multivarka-skorovarka-tefal-cy625d32-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/79f64a6ea6582eb0/multivarka-skorovarka-tefal-cy625d32-cernyj/characteristics/', 'Тип': 'мультиварка-скороварка', 'Модель': 'Tefal CY625D32'}
# {'source': '/content/data/ventilator-reoka-rktf-4001--belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/915c470890a4ed20/ventilator-reoka-rktf-4001--belyj/characteristics/', 'Тип': 'вентилятор', 'Модель': 'REOKA RKTF-4001'}
# {'source': '/content/data/gazovaa-plita-flama-rg-24051-w-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/357af32241966606/gazovaa-plita-flama-rg-24051-w-belyj/characteristics/', 'Тип': 'газовая плита', 'Модель': 'Flama RG 24051 W'}
# {'source': '/content/data/pylesos-starwind-scv2285-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/e26aa042439db152/pylesos-starwind-scv2285-cernyj/characteristics/', 'Тип': 'пылесос', 'Модель': 'Starwind SCV2285'}
# {'source': '/content/data/mini-pec-dexp-vn-3800-hp-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/dca4d6b6fa12ed20/mini-pec-dexp-vn-3800-hp-cernyj/characteristics/', 'Тип': 'мини-печь', 'Модель': 'DEXP VN-3800 HP'}
# {'source': '/content/data/multivarka-redmond-mc100s-seryj.txt', 'Источник': 'https://www.dns-shop.ru/product/b51f2d4b5eccd582/multivarka-redmond-mc100s-seryj/characteristics/', 'Тип': 'мультиварка', 'Модель': 'Redmond MC100S'}
# {'source': '/content/data/multivarka-aceline-amc865-serebristyj.txt', 'Источник': 'https://www.dns-shop.ru/product/e6a94c30a752ed20/multivarka-aceline-amc865-serebristyj/characteristics/', 'Тип': 'мультиварка', 'Модель': 'Aceline AMC865'}
# {'source': '/content/data/kondicioner-nastennyj-split-sistema-samsung-ar09txhqasinua-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/0ca1539783e8ed20/kondicioner-nastennyj-split-sistema-samsung-ar09txhqasinua-belyj/characteristics/', 'Тип': 'кондиционер', 'Модель': 'Samsung AR09TXHQASINUA'}
# {'source': '/content/data/pylesos-pioneer-vc345c-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/477ed36989ff2ff4/pylesos-pioneer-vc345c-cernyj/characteristics/', 'Тип': 'пылесос', 'Модель': 'Pioneer VC345C'}
# {'source': '/content/data/kombinirovannaa-plita-gefest-pge-6302-03-0040-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/e710ada9343efefa/kombinirovannaa-plita-gefest-pge-6302-03-0040-belyj/characteristics/', 'Тип': 'плита комбинированная', 'Модель': 'Gefest ПГЭ 6302-03 0040'}
# {'source': '/content/data/pylesos-kitfort-kt-5323-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/60dac80dd5483697/pylesos-kitfort-kt-5323-cernyj/characteristics/', 'Тип': 'пылесос', 'Модель': 'Kitfort KT-5323'}
# {'source': '/content/data/pylesos-bosch-serie-4-propower-bwd421pow-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/1dae32ecf96a1b80/pylesos-bosch-serie-4-propower-bwd421pow-cernyj/characteristics/', 'Тип': 'пылесос', 'Модель': 'Bosch Serie 4 ProPower BWD421POW'}
# {'source': '/content/data/masorubka-elektriceskaa-moulinex-hv3-me306832-seryj.txt', 'Источник': 'https://www.dns-shop.ru/product/2420458b07c33330/masorubka-elektriceskaa-moulinex-hv3-me306832-seryj/characteristics/', 'Тип': 'мясорубка электрическая', 'Модель': 'Moulinex HV3 ME306832'}
# {'source': '/content/data/masorubka-elektriceskaa-dexp-mm-1800-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/961636b9100ced20/masorubka-elektriceskaa-dexp-mm-1800-cernyj/characteristics/', 'Тип': 'мясорубка электрическая', 'Модель': 'DEXP MM-1800'}
# {'source': '/content/data/ventilator-primera-tfp-1513jc--belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/d59f83441639278f/ventilator-primera-tfp-1513jc--belyj/characteristics/', 'Тип': 'вентилятор', 'Модель': 'Primera TFP-1513JC'}
# {'source': '/content/data/multivarka-redmond-skycooker-rmc-m226s-serebristyj.txt', 'Источник': 'https://www.dns-shop.ru/product/b138ff6424513330/multivarka-redmond-skycooker-rmc-m226s-serebristyj/characteristics/', 'Тип': 'мультиварка', 'Модель': 'Redmond SkyCooker RMC-M226S'}
# {'source': '/content/data/multivarka-redmond-rmc-m52-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/ab2eb11fdfef7a61/multivarka-redmond-rmc-m52-cernyj/characteristics/', 'Тип': 'мультиварка', 'Модель': 'Redmond RMC-M52'}
# {'source': '/content/data/kondicioner-nastennyj-split-sistema-tcl-breezein-09-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/c45340a55845ed20/kondicioner-nastennyj-split-sistema-tcl-breezein-09-belyj/characteristics/', 'Тип': 'кондиционер', 'Модель': 'TCL BREEZEIN 09'}
# {'source': '/content/data/pylesos-bosch-bgl8pow2-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/4d8abea15f60ed20/pylesos-bosch-bgl8pow2-cernyj/characteristics/', 'Тип': 'пылесос', 'Модель': 'Bosch BGL8POW2'}
# {'source': '/content/data/multivarka-tefal-efficient-rk815832-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/40e1b7f8aa593330/multivarka-tefal-efficient-rk815832-cernyj/characteristics/', 'Тип': 'мультиварка', 'Модель': 'Tefal Efficient RK815832'}
# {'source': '/content/data/mini-pec-hyundai-mio-hy082-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/ff49b75071bc5797/mini-pec-hyundai-mio-hy082-cernyj/characteristics/', 'Тип': 'мини-печь', 'Модель': 'Hyundai MIO-HY082'}
# {'source': '/content/data/multivarka-redmond-rmc-03-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/69091fcd76153330/multivarka-redmond-rmc-03-cernyj/characteristics/', 'Тип': 'мультиварка', 'Модель': 'Redmond RMC-03'}
# {'source': '/content/data/ventilator-reoka-rkbf-3501--belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/c227f449a138ed20/ventilator-reoka-rkbf-3501--belyj/characteristics/', 'Тип': 'вентилятор', 'Модель': 'REOKA RKBF-3501'}
# {'source': '/content/data/gazovaa-plita-darina-f1-3110-w-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/385526d101641b80/gazovaa-plita-darina-f1-3110-w-belyj/characteristics/', 'Тип': 'газовая плита', 'Модель': 'DARINA F1 3110 W'}
# {'source': '/content/data/mini-pec-dexp-vn-4500-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/37e957e3fa11ed20/mini-pec-dexp-vn-4500-cernyj/characteristics/', 'Тип': 'мини-печь', 'Модель': 'DEXP VN-4500'}
# {'source': '/content/data/ventilator-tefal-essential-stand-vf4420f0--cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/a001f9d495b33333/ventilator-tefal-essential-stand-vf4420f0--cernyj/characteristics/', 'Тип': 'вентилятор', 'Модель': 'Tefal Essential+ Stand VF4420F0'}
# {'source': '/content/data/pylesos-scarlett-sc-vc80c307-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/827846c07d9d1634/pylesos-scarlett-sc-vc80c307-cernyj/characteristics/', 'Тип': 'пылесос', 'Модель': 'Scarlett SC-VC80C307'}
# {'source': '/content/data/mini-pec-kraft-kf-mo-3801-w-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/600e4fa7468d3330/mini-pec-kraft-kf-mo-3801-w-belyj/characteristics/', 'Тип': 'мини-печь', 'Модель': 'Kraft KF-MO 3801 W'}
# {'source': '/content/data/gazovaa-plita-darina-s-5001-w-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/b2f1ae8a664e8d8b/gazovaa-plita-darina-s-5001-w-belyj/characteristics/', 'Тип': 'газовая плита', 'Модель': 'DARINA S 5001 W'}
# {'source': '/content/data/ventilator-xiaomi-mi-smart-standing-fan-2-lite--belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/7a155a061f4ced20/ventilator-xiaomi-mi-smart-standing-fan-2-lite--belyj/characteristics/', 'Тип': 'вентилятор', 'Модель': 'Xiaomi Mi Smart Standing Fan 2 Lite'}
# {'source': '/content/data/kondicioner-nastennyj-split-sistema-iffalcon-f1-inv-09-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/21a6e98d583bed20/kondicioner-nastennyj-split-sistema-iffalcon-f1-inv-09-belyj/characteristics/', 'Тип': 'кондиционер', 'Модель': 'iFFALCON F1 INV 09'}
# {'source': '/content/data/ventilator-stadler-form-charly-new-little-c-040--seryj.txt', 'Источник': 'https://www.dns-shop.ru/product/8f99178531c13330/ventilator-stadler-form-charly-new-little-c-040--seryj/characteristics/', 'Тип': 'вентилятор', 'Модель': 'Stadler Form Charly NEW Little C-040'}
# {'source': '/content/data/gazovaa-plita-gefest-gs-3208-w-gc-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/f63fccf91b286bc2/gazovaa-plita-gefest-gs-3208-w-gc-belyj/characteristics/', 'Тип': 'газовая плита', 'Модель': 'Gefest GS 3208 W GC'}
# {'source': '/content/data/ventilator-electrolux-eff-1030w--belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/3d22ad153c0e30ef/ventilator-electrolux-eff-1030w--belyj/characteristics/', 'Тип': 'вентилятор', 'Модель': 'Electrolux EFF-1030w'}
# {'source': '/content/data/masorubka-elektriceskaa-dexp-mm-2000-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/10180c74100ced20/masorubka-elektriceskaa-dexp-mm-2000-belyj/characteristics/', 'Тип': 'мясорубка электрическая', 'Модель': 'DEXP MM-2000'}
# {'source': '/content/data/pylesos-bosch-bgs21pow2-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/c3241150bf5beb77/pylesos-bosch-bgs21pow2-cernyj/characteristics/', 'Тип': 'пылесос', 'Модель': 'Bosch BGS21POW2'}
# {'source': '/content/data/mini-pec-dexp-eo-2038b-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/d3acde212c952d19/mini-pec-dexp-eo-2038b-cernyj/characteristics/', 'Тип': 'мини-печь', 'Модель': 'DEXP EO-2038B'}
# {'source': '/content/data/masorubka-elektriceskaa-kenwood-mg450-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/8bd63ccc27b5526f/masorubka-elektriceskaa-kenwood-mg450-belyj/characteristics/', 'Тип': 'мясорубка электрическая', 'Модель': 'Kenwood MG450'}
# {'source': '/content/data/pylesos-kitfort-kt-5193-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/07b544118de0c6b8/pylesos-kitfort-kt-5193-cernyj/characteristics/', 'Тип': 'пылесос', 'Модель': 'Kitfort КТ-5193'}
# {'source': '/content/data/ventilator-ballu-bff-806--belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/5187fc351a9e2960/ventilator-ballu-bff-806--belyj/characteristics/', 'Тип': 'вентилятор', 'Модель': 'Ballu BFF-806'}
# {'source': '/content/data/kondicioner-nastennyj-split-sistema-centek-ct-65a09-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/7d6c20080a3a3330/kondicioner-nastennyj-split-sistema-centek-ct-65a09-belyj/characteristics/', 'Тип': 'кондиционер', 'Модель': 'Centek CT-65A09'}
# {'source': '/content/data/ventilator-electrolux-eff-1020w--belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/8ca04488802ba97b/ventilator-electrolux-eff-1020w--belyj/characteristics/', 'Тип': 'вентилятор', 'Модель': 'Electrolux EFF-1020w'}
# {'source': '/content/data/gazovaa-plita-darina-s4-gm-441-101-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/5d47a3ce4fb03361/gazovaa-plita-darina-s4-gm-441-101-belyj/characteristics/', 'Тип': 'газовая плита', 'Модель': 'DARINA S4 GM 441 101'}
# {'source': '/content/data/ventilator-electrolux-eff-1003d--belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/0be27770146f3332/ventilator-electrolux-eff-1003d--belyj/characteristics/', 'Тип': 'вентилятор', 'Модель': 'Electrolux EFF-1003D'}
# {'source': '/content/data/mini-pec-redmond-ro-5701-seryj.txt', 'Источник': 'https://www.dns-shop.ru/product/e02785cd23253330/mini-pec-redmond-ro-5701-seryj/characteristics/', 'Тип': 'мини-печь', 'Модель': 'Redmond RO-5701'}
# {'source': '/content/data/gazovaa-plita-gefest-1200-s6-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/50d4341188953120/gazovaa-plita-gefest-1200-s6-belyj/characteristics/', 'Тип': 'газовая плита', 'Модель': 'Gefest 1200 С6'}
# {'source': '/content/data/pylesos-samsung-sc4581-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/ccac80f3a655d9cb/pylesos-samsung-sc4581-cernyj/characteristics/', 'Тип': 'пылесос', 'Модель': 'Samsung SC4581'}
# {'source': '/content/data/mini-pec-centek-ct-1531-42-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/f5f8c36c23243330/mini-pec-centek-ct-1531-42-cernyj/characteristics/', 'Тип': 'мини-печь', 'Модель': 'Centek CT-1531-42'}
# {'source': '/content/data/multivarka-polaris-pmc-0586ad-serebristyj.txt', 'Источник': 'https://www.dns-shop.ru/product/094ccd55e6353330/multivarka-polaris-pmc-0586ad-serebristyj/characteristics/', 'Тип': 'мультиварка', 'Модель': 'Polaris PMC 0586AD'}
# {'source': '/content/data/multivarka-skorovarka-tefal-cy621d32-serebristyj.txt', 'Источник': 'https://www.dns-shop.ru/product/f456cc71e63f3330/multivarka-skorovarka-tefal-cy621d32-serebristyj/characteristics/', 'Тип': 'мультиварка-скороварка', 'Модель': 'Tefal CY621D32'}
# {'source': '/content/data/gazovaa-plita-gorenje-gg5a12wh-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/5997018fb22ee58b/gazovaa-plita-gorenje-gg5a12wh-belyj/characteristics/', 'Тип': 'газовая плита', 'Модель': 'Gorenje GG5A12WH'}
# {'source': '/content/data/kombinirovannaa-plita-gefest-5102-03-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/fc55ce53a4993330/kombinirovannaa-plita-gefest-5102-03-belyj/characteristics/', 'Тип': 'плита комбинированная', 'Модель': 'Gefest 5102-03'}
# {'source': '/content/data/gazovaa-plita-gefest-gs-6515-b1-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/8a91436330b83330/gazovaa-plita-gefest-gs-6515-b1-cernyj/characteristics/', 'Тип': 'газовая плита', 'Модель': 'Gefest GS 6515 B1'}
# {'source': '/content/data/gazovaa-plita-gefest-pg-5100-03-0004-serebristyj.txt', 'Источник': 'https://www.dns-shop.ru/product/ed4ab46b1d3c3332/gazovaa-plita-gefest-pg-5100-03-0004-serebristyj/characteristics/', 'Тип': 'газовая плита', 'Модель': 'Gefest ПГ 5100-03 0004'}
# {'source': '/content/data/multivarka-redmond-mc109-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/9aaf5337e46786f9/multivarka-redmond-mc109-cernyj/characteristics/', 'Тип': 'мультиварка', 'Модель': 'Redmond MC109'}
# {'source': '/content/data/multivarka-skorovarka-redmond-rmc-p350-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/438a1e5a4c063330/multivarka-skorovarka-redmond-rmc-p350-belyj/characteristics/', 'Тип': 'мультиварка-скороварка', 'Модель': 'Redmond RMC-P350'}
# {'source': '/content/data/ventilator-electrolux-eft-1110w--belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/3b80c0bf7d5a2641/ventilator-electrolux-eft-1110w--belyj/characteristics/', 'Тип': 'вентилятор', 'Модель': 'Electrolux EFT-1110w'}
# {'source': '/content/data/pylesos-dexp-vl-2300s-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/48c287d605b2ed20/pylesos-dexp-vl-2300s-cernyj/characteristics/', 'Тип': 'пылесос', 'Модель': 'DEXP VL-2300S'}
# {'source': '/content/data/kondicioner-nastennyj-split-sistema-tcl-eli-inv-07-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/b802277e5843ed20/kondicioner-nastennyj-split-sistema-tcl-eli-inv-07-belyj/characteristics/', 'Тип': 'кондиционер', 'Модель': 'TCL ELI INV 07'}
# {'source': '/content/data/masorubka-elektriceskaa-dexp-mgp-2000-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/4c494324fdd2ed20/masorubka-elektriceskaa-dexp-mgp-2000-belyj/characteristics/', 'Тип': 'мясорубка электрическая', 'Модель': 'DEXP MGP-2000'}
# {'source': '/content/data/ventilator-midea-fs4072--belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/23427587f34bf742/ventilator-midea-fs4072--belyj/characteristics/', 'Тип': 'вентилятор', 'Модель': 'Midea FS4072'}
# {'source': '/content/data/masorubka-elektriceskaa-polaris-pmg-2583-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/754ff145ddf32ff2/masorubka-elektriceskaa-polaris-pmg-2583-cernyj/characteristics/', 'Тип': 'мясорубка электрическая', 'Модель': 'Polaris PMG 2583'}
# {'source': '/content/data/kombinirovannaa-plita-gefest-pge-5302-03-0040-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/253807fb799a1b5a/kombinirovannaa-plita-gefest-pge-5302-03-0040-belyj/characteristics/', 'Тип': 'плита комбинированная', 'Модель': 'Gefest ПГЭ 5302-03 0040'}
# {'source': '/content/data/multivarka-skorovarka-moulinex-ce5a0f32-bronzovyj.txt', 'Источник': 'https://www.dns-shop.ru/product/61f2163488f43332/multivarka-skorovarka-moulinex-ce5a0f32-bronzovyj/characteristics/', 'Тип': 'мультиварка-скороварка', 'Модель': 'MOULINEX CE5A0F32'}
# {'source': '/content/data/multivarka-polaris-pmc-0517-expert-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/46855e96dcee1b80/multivarka-polaris-pmc-0517-expert-cernyj/characteristics/', 'Тип': 'мультиварка', 'Модель': 'Polaris PMC 0517 Expert'}
# {'source': '/content/data/holodilnik-kompaktnyj--indesit-itd-125-w-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/6dc185b42d6f3332/holodilnik-kompaktnyj--indesit-itd-125-w-belyj/characteristics/', 'Тип': 'холодильник компактный', 'Модель': 'Indesit ITD 125 W'}
# {'source': '/content/data/pylesos-kitfort-kt-5353-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/3d8471ffb2b19ee1/pylesos-kitfort-kt-5353-cernyj/characteristics/', 'Тип': 'пылесос', 'Модель': 'Kitfort КТ-5353'}
# {'source': '/content/data/multivarka-polaris-pmc-0576ads-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/3d9380cc27c83333/multivarka-polaris-pmc-0576ads-cernyj/characteristics/', 'Тип': 'мультиварка', 'Модель': 'Polaris PMC 0576ADS'}
# {'source': '/content/data/pylesos-thomas-788599-drybox-amfibia-family-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/3069850ad81d3330/pylesos-thomas-788599-drybox-amfibia-family-cernyj/characteristics/', 'Тип': 'пылесос', 'Модель': 'Thomas 788599 DRYBOX AMFIBIA FAMILY'}
# {'source': '/content/data/multivarka-aceline-amc553h-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/647a726f1633ed20/multivarka-aceline-amc553h-cernyj/characteristics/', 'Тип': 'мультиварка', 'Модель': 'Aceline AMC553H'}
# {'source': '/content/data/kombinirovannaa-plita-gefest-pge-6302-04-0040-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/41adac3779c93e1c/kombinirovannaa-plita-gefest-pge-6302-04-0040-belyj/characteristics/', 'Тип': 'плита комбинированная', 'Модель': 'Gefest ПГЭ 6302-04 0040'}
# {'source': '/content/data/multivarka-aceline-amc864s-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/cbb601fa1634ed20/multivarka-aceline-amc864s-cernyj/characteristics/', 'Тип': 'мультиварка', 'Модель': 'Aceline AMC864S'}
# {'source': '/content/data/gazovaa-plita-gefest-gs-32w633-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/0d68545e643c3332/gazovaa-plita-gefest-gs-32w633-belyj/characteristics/', 'Тип': 'газовая плита', 'Модель': 'Gefest GS 32W633'}
# {'source': '/content/data/kombinirovannaa-plita-gefest-pge-5302-03-0046-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/781cc7d2991634c2/kombinirovannaa-plita-gefest-pge-5302-03-0046-cernyj/characteristics/', 'Тип': 'плита комбинированная', 'Модель': 'Gefest ПГЭ 5302-03 0046'}
# {'source': '/content/data/mini-pec-kraft-kfc-mo-90-hw-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/0c4739cf132ddff1/mini-pec-kraft-kfc-mo-90-hw-belyj/characteristics/', 'Тип': 'мини-печь', 'Модель': 'Kraft KFC-MO 90 HW'}
# {'source': '/content/data/kondicioner-nastennyj-split-sistema-tcl-eli-onf-07-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/7598b13f5841ed20/kondicioner-nastennyj-split-sistema-tcl-eli-onf-07-belyj/characteristics/', 'Тип': 'кондиционер', 'Модель': 'TCL ELI ONF 07'}
# {'source': '/content/data/masorubka-elektriceskaa-scarlett-sc-mg45s65-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/7951bca883e42ff4/masorubka-elektriceskaa-scarlett-sc-mg45s65-belyj/characteristics/', 'Тип': 'мясорубка электрическая', 'Модель': 'Scarlett SC-MG45S65'}
# {'source': '/content/data/kombinirovannaa-plita-gefest-pge-5102-01-0194-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/94bb582c8f92b857/kombinirovannaa-plita-gefest-pge-5102-01-0194-cernyj/characteristics/', 'Тип': 'плита комбинированная', 'Модель': 'Gefest ПГЭ 5102-01 0194'}
# {'source': '/content/data/ventilator-timberk-t-sf1602--cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/aee879557da22ff4/ventilator-timberk-t-sf1602--cernyj/characteristics/', 'Тип': 'вентилятор', 'Модель': 'Timberk T-SF1602'}
# {'source': '/content/data/ventilator-rix-rdf-1501usb--cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/4ba575370c5e909d/ventilator-rix-rdf-1501usb--cernyj/characteristics/', 'Тип': 'вентилятор', 'Модель': 'Rix RDF-1501USB'}
# {'source': '/content/data/holodilnik-s-morozilnikom--dexp-b2-26aha-serebristyj.txt', 'Источник': 'https://www.dns-shop.ru/product/9729704ab954ed20/holodilnik-s-morozilnikom--dexp-b2-26aha-serebristyj/characteristics/', 'Тип': 'холодильник полноразмерный с морозильником', 'Модель': 'DEXP B2-26AHA'}
# {'source': '/content/data/pylesos-tefal-compact-power-xxl-tw4b75ea-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/38e14ae398aed21a/pylesos-tefal-compact-power-xxl-tw4b75ea-cernyj/characteristics/', 'Тип': 'пылесос', 'Модель': 'Tefal Compact Power XXL TW4B75EA'}
# {'source': '/content/data/masorubka-elektriceskaa-moulinex-classic-me105830-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/6f2f9da2fd3e3330/masorubka-elektriceskaa-moulinex-classic-me105830-cernyj/characteristics/', 'Тип': 'мясорубка электрическая', 'Модель': 'Moulinex Classic ME105830'}
# {'source': '/content/data/gazovaa-plita-gefest-gs-3208-b-koricnevyj.txt', 'Источник': 'https://www.dns-shop.ru/product/ab74b99054133330/gazovaa-plita-gefest-gs-3208-b-koricnevyj/characteristics/', 'Тип': 'газовая плита', 'Модель': 'Gefest GS 3208 B'}
# {'source': '/content/data/masorubka-elektriceskaa-aksion-m32101-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/5bcf2dc37b40a1df/masorubka-elektriceskaa-aksion-m32101-belyj/characteristics/', 'Тип': 'мясорубка электрическая', 'Модель': 'Аксион М321.01'}
# {'source': '/content/data/mini-pec-dexp-vn-3000-ss-serebristyj.txt', 'Источник': 'https://www.dns-shop.ru/product/ff07d07afa0fed20/mini-pec-dexp-vn-3000-ss-serebristyj/characteristics/', 'Тип': 'мини-печь', 'Модель': 'DEXP VN-3000 SS'}
# {'source': '/content/data/mini-pec-aceline-vn-900-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/b2ce5c83f728ed20/mini-pec-aceline-vn-900-cernyj/characteristics/', 'Тип': 'мини-печь', 'Модель': 'Aceline VN-900'}
# {'source': '/content/data/ventilator-xiaomi-mi-smart-standing-fan-pro--belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/bf08b61959633332/ventilator-xiaomi-mi-smart-standing-fan-pro--belyj/characteristics/', 'Тип': 'вентилятор', 'Модель': 'Xiaomi Mi Smart Standing Fan Pro'}
# {'source': '/content/data/multivarka-polaris-pmc-0528-wi-fi-iq-home-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/2c28dd65c8032eb0/multivarka-polaris-pmc-0528-wi-fi-iq-home-cernyj/characteristics/', 'Тип': 'мультиварка', 'Модель': 'Polaris PMC 0528 Wi-FI IQ Home'}
# {'source': '/content/data/masorubka-elektriceskaa-reoka-rkmg-ma221-serebristyj.txt', 'Источник': 'https://www.dns-shop.ru/product/7006b5a81851ed20/masorubka-elektriceskaa-reoka-rkmg-ma221-serebristyj/characteristics/', 'Тип': 'мясорубка электрическая', 'Модель': 'Reoka RKMG-MA221'}
# {'source': '/content/data/masorubka-elektriceskaa-moulinex-hv4-me462132-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/60b267283abb2ff2/masorubka-elektriceskaa-moulinex-hv4-me462132-belyj/characteristics/', 'Тип': 'мясорубка электрическая', 'Модель': 'Moulinex HV4 ME462132'}
# {'source': '/content/data/gazovaa-plita-darina-f1-3015w-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/2067f8889e2f1b80/gazovaa-plita-darina-f1-3015w-belyj/characteristics/', 'Тип': 'газовая плита', 'Модель': 'DARINA F1 3015W'}
# {'source': '/content/data/ventilator-zdk-fan-as-006--sinij.txt', 'Источник': 'https://www.dns-shop.ru/product/d74f7e4bbc9b3737/ventilator-zdk-fan-as-006--sinij/characteristics/', 'Тип': 'вентилятор', 'Модель': 'ZDK FAN AS-006'}
# {'source': '/content/data/kondicioner-nastennyj-split-sistema-tcl-eli-inv-09-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/50ad84245844ed20/kondicioner-nastennyj-split-sistema-tcl-eli-inv-09-belyj/characteristics/', 'Тип': 'кондиционер', 'Модель': 'TCL ELI INV 09'}
# {'source': '/content/data/pylesos-samsung-sc8876-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/68bac2f488bc3330/pylesos-samsung-sc8876-cernyj/characteristics/', 'Тип': 'пылесос', 'Модель': 'Samsung SC8876'}
# {'source': '/content/data/kombinirovannaa-plita-gefest-pge-6102-01-0197-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/5b25928206c7b3ae/kombinirovannaa-plita-gefest-pge-6102-01-0197-cernyj/characteristics/', 'Тип': 'плита комбинированная', 'Модель': 'Gefest ПГЭ 6102-01 0197'}
# {'source': '/content/data/pylesos-samsung-vc4100-sc15k4169hd-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/df23054f88bd1b80/pylesos-samsung-vc4100-sc15k4169hd-cernyj/characteristics/', 'Тип': 'пылесос', 'Модель': 'Samsung VC4100 (SC15K4169HD)'}
# {'source': '/content/data/ventilator-electrolux-etf-108w--belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/ad49b2d7c557b1d5/ventilator-electrolux-etf-108w--belyj/characteristics/', 'Тип': 'вентилятор', 'Модель': 'Electrolux ETF-108W'}
# {'source': '/content/data/pylesos-hyundai-hyv-c5455-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/3f41b1eb0739ed73/pylesos-hyundai-hyv-c5455-cernyj/characteristics/', 'Тип': 'пылесос', 'Модель': 'Hyundai HYV-C5455'}
# {'source': '/content/data/gazovaa-plita-gefest-3200-06-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/50d4340d88953120/gazovaa-plita-gefest-3200-06-belyj/characteristics/', 'Тип': 'газовая плита', 'Модель': 'Gefest 3200-06'}
# {'source': '/content/data/ventilator-ballu-bff-840--belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/cd72119489bdfe18/ventilator-ballu-bff-840--belyj/characteristics/', 'Тип': 'вентилятор', 'Модель': 'Ballu BFF-840'}
# {'source': '/content/data/kombinirovannaa-plita-gefest-ge-553044-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/9cdbf26a643c3332/kombinirovannaa-plita-gefest-ge-553044-cernyj/characteristics/', 'Тип': 'плита комбинированная', 'Модель': 'Gefest GE 553044'}
# {'source': '/content/data/masorubka-elektriceskaa-redmond-rmg-1223-6-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/d2c33a80f7383330/masorubka-elektriceskaa-redmond-rmg-1223-6-cernyj/characteristics/', 'Тип': 'мясорубка электрическая', 'Модель': 'Redmond RMG-1223-6'}
# {'source': '/content/data/masorubka-elektriceskaa-aksion-m-4103-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/618fedcff7493330/masorubka-elektriceskaa-aksion-m-4103-belyj/characteristics/', 'Тип': 'мясорубка электрическая', 'Модель': 'Аксион М 41.03'}
# {'source': '/content/data/ventilator-scarlett-sc-df111s09--cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/a3f335f260ed3330/ventilator-scarlett-sc-df111s09--cernyj/characteristics/', 'Тип': 'вентилятор', 'Модель': 'Scarlett SC-DF111S09'}
# {'source': '/content/data/pylesos-kitfort-kt-5144-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/c5d882d9214e467a/pylesos-kitfort-kt-5144-cernyj/characteristics/', 'Тип': 'пылесос', 'Модель': 'Kitfort КТ-5144'}
# {'source': '/content/data/mini-pec-simfer-m3420-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/f6c20263744a3330/mini-pec-simfer-m3420-belyj/characteristics/', 'Тип': 'мини-печь', 'Модель': 'Simfer M3420'}
# {'source': '/content/data/multivarka-dexp-dmc-865l-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/247b006ec30d8888/multivarka-dexp-dmc-865l-cernyj/characteristics/', 'Тип': 'мультиварка', 'Модель': 'DEXP DMC-865L'}
# {'source': '/content/data/multivarka-redmond-mc100-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/8f8422e2e816b0d9/multivarka-redmond-mc100-cernyj/characteristics/', 'Тип': 'мультиварка', 'Модель': 'Redmond MC100'}
# {'source': '/content/data/multivarka-polaris-pmc-0530-wi-fi-iq-home-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/2c28dd67c8032eb0/multivarka-polaris-pmc-0530-wi-fi-iq-home-cernyj/characteristics/', 'Тип': 'мультиварка', 'Модель': 'Polaris PMC 0530 Wi-FI IQ Home'}
# {'source': '/content/data/multivarka-polaris-pmc-0365ad-serebristyj.txt', 'Источник': 'https://www.dns-shop.ru/product/a341ae05258e3330/multivarka-polaris-pmc-0365ad-serebristyj/characteristics/', 'Тип': 'мультиварка', 'Модель': 'Polaris PMC 0365AD'}
# {'source': '/content/data/multivarka-skorovarka-redmond-mp110-seryj.txt', 'Источник': 'https://www.dns-shop.ru/product/6eb4acc55de437d0/multivarka-skorovarka-redmond-mp110-seryj/characteristics/', 'Тип': 'мультиварка-скороварка', 'Модель': 'Redmond MP110'}
# {'source': '/content/data/pylesos-philips-fc957101-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/649e845ad216d9cb/pylesos-philips-fc957101-cernyj/characteristics/', 'Тип': 'пылесос', 'Модель': 'Philips FC9571/01'}
# {'source': '/content/data/ventilator-reoka-rksf-c3600--serebristyj.txt', 'Источник': 'https://www.dns-shop.ru/product/0aab114cc15c7f5e/ventilator-reoka-rksf-c3600--serebristyj/characteristics/', 'Тип': 'вентилятор', 'Модель': 'Reoka RKSF-C3600'}
# {'source': '/content/data/mini-pec-aceline-vn-6000-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/1a9d9258816ec820/mini-pec-aceline-vn-6000-cernyj/characteristics/', 'Тип': 'мини-печь', 'Модель': 'Aceline VN-6000'}
# {'source': '/content/data/multivarka-redmond-rmc-m95-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/13c73162e09c3330/multivarka-redmond-rmc-m95-cernyj/characteristics/', 'Тип': 'мультиварка', 'Модель': 'Redmond RMC-M95'}
# {'source': '/content/data/kondicioner-nastennyj-split-sistema-centek-ct-65a07-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/df68741e25cd3332/kondicioner-nastennyj-split-sistema-centek-ct-65a07-belyj/characteristics/', 'Тип': 'кондиционер', 'Модель': 'Centek CT-65A07+'}
# {'source': '/content/data/gazovaa-plita-gorenje-gg5a12wf-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/49ba0455d2f75a1c/gazovaa-plita-gorenje-gg5a12wf-belyj/characteristics/', 'Тип': 'газовая плита', 'Модель': 'Gorenje GG5A12WF'}
# {'source': '/content/data/ventilator-brayer-br4978--cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/3a1de12b285c452b/ventilator-brayer-br4978--cernyj/characteristics/', 'Тип': 'вентилятор', 'Модель': 'Brayer BR4978'}
# {'source': '/content/data/mini-pec-dexp-eo-1320-ss-serebristyj.txt', 'Источник': 'https://www.dns-shop.ru/product/fb23c3cec0bfba29/mini-pec-dexp-eo-1320-ss-serebristyj/characteristics/', 'Тип': 'мини-печь', 'Модель': 'DEXP EO-1320 SS'}
# {'source': '/content/data/ventilator-xiaomi-smart-standing-fan-2--belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/43dcfdcd11e2ed20/ventilator-xiaomi-smart-standing-fan-2--belyj/characteristics/', 'Тип': 'вентилятор', 'Модель': 'Xiaomi Smart Standing Fan 2'}
# {'source': '/content/data/masorubka-elektriceskaa-redmond-rmg-1239-6-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/4bdcb05d27dba70d/masorubka-elektriceskaa-redmond-rmg-1239-6-cernyj/characteristics/', 'Тип': 'мясорубка электрическая', 'Модель': 'Redmond RMG-1239-6'}
# {'source': '/content/data/pylesos-thomas-vestfalia-xt-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/9c5c16eb8c5d3120/pylesos-thomas-vestfalia-xt-cernyj/characteristics/', 'Тип': 'пылесос', 'Модель': 'THOMAS VESTFALIA XT'}
# {'source': '/content/data/pylesos-bosch-bgbs2ba1p-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/dda08c34de9a2ffc/pylesos-bosch-bgbs2ba1p-cernyj/characteristics/', 'Тип': 'пылесос', 'Модель': 'Bosch BGBS2BA1P'}
# {'source': '/content/data/kombinirovannaa-plita-darina-s-5302-w-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/61a2294186494ded/kombinirovannaa-plita-darina-s-5302-w-belyj/characteristics/', 'Тип': 'плита комбинированная', 'Модель': 'Darina S 5302 W'}
# {'source': '/content/data/pylesos-samsung-vc18m31d9hd-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/31d5adc899623330/pylesos-samsung-vc18m31d9hd-cernyj/characteristics/', 'Тип': 'пылесос', 'Модель': 'Samsung VC18M31D9HD'}
# {'source': '/content/data/multivarka-tefal-multicookstir-rk901f32-zolotistyj.txt', 'Источник': 'https://www.dns-shop.ru/product/5fedf666d2893330/multivarka-tefal-multicookstir-rk901f32-zolotistyj/characteristics/', 'Тип': 'мультиварка', 'Модель': 'Tefal Multicook&Stir RK901F32'}
# {'source': '/content/data/gazovaa-plita-gefest-gs-513002-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/4f2720ae643c3332/gazovaa-plita-gefest-gs-513002-belyj/characteristics/', 'Тип': 'газовая плита', 'Модель': 'Gefest GS 513002'}
# {'source': '/content/data/multivarka-aceline-amc865tp-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/39266150e244ed20/multivarka-aceline-amc865tp-cernyj/characteristics/', 'Тип': 'мультиварка', 'Модель': 'Aceline AMC865TP'}
# {'source': '/content/data/pylesos-lg-vk69662n-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/cde7290bfda6ed20/pylesos-lg-vk69662n-cernyj/characteristics/', 'Тип': 'пылесос', 'Модель': 'LG VK69662N'}
# {'source': '/content/data/ventilator-brayer-br4977--seryj.txt', 'Источник': 'https://www.dns-shop.ru/product/4c205e9735dee976/ventilator-brayer-br4977--seryj/characteristics/', 'Тип': 'вентилятор', 'Модель': 'Brayer BR4977'}
# {'source': '/content/data/kondicioner-nastennyj-split-sistema-electrolux-eacs-07hatn3_21y-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/2fdb02b0d12d3330/kondicioner-nastennyj-split-sistema-electrolux-eacs-07hatn3_21y-belyj/characteristics/', 'Тип': 'кондиционер', 'Модель': 'Electrolux EACS-07HAT/N3_21Y'}
# {'source': '/content/data/masorubka-elektriceskaa-polaris-pmg-2585a-rus-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/1d0b727af8fa5c60/masorubka-elektriceskaa-polaris-pmg-2585a-rus-cernyj/characteristics/', 'Тип': 'мясорубка электрическая', 'Модель': 'Polaris PMG 2585A RUS'}
# {'source': '/content/data/gazovaa-plita-gefest-3200-06-k62-serebristyj.txt', 'Источник': 'https://www.dns-shop.ru/product/3f97efb8a4883330/gazovaa-plita-gefest-3200-06-k62-serebristyj/characteristics/', 'Тип': 'газовая плита', 'Модель': 'Gefest 3200-06 К62'}
# {'source': '/content/data/ventilator-midea-fs4070d--cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/995fd4ee4462acce/ventilator-midea-fs4070d--cernyj/characteristics/', 'Тип': 'вентилятор', 'Модель': 'Midea FS4070D'}
# {'source': '/content/data/ventilator-rix-npsf-8000w--serebristyj.txt', 'Источник': 'https://www.dns-shop.ru/product/a9e0c59360c3cdcb/ventilator-rix-npsf-8000w--serebristyj/characteristics/', 'Тип': 'вентилятор', 'Модель': 'Rix NPSF-8000W'}
# {'source': '/content/data/masorubka-elektriceskaa-dexp-mgp-1800-koricnevyj.txt', 'Источник': 'https://www.dns-shop.ru/product/d2bf2127f68e3330/masorubka-elektriceskaa-dexp-mgp-1800-koricnevyj/characteristics/', 'Тип': 'мясорубка электрическая', 'Модель': 'DEXP MGP-1800'}
# {'source': '/content/data/masorubka-elektriceskaa-polaris-pmg-1875-rus-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/8c853ef85cb8613f/masorubka-elektriceskaa-polaris-pmg-1875-rus-belyj/characteristics/', 'Тип': 'мясорубка электрическая', 'Модель': 'Polaris PMG 1875 RUS'}
# {'source': '/content/data/mini-pec-kraft-technology-tch-mo-6011-rkgl-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/c1f4ce902e0c3333/mini-pec-kraft-technology-tch-mo-6011-rkgl-cernyj/characteristics/', 'Тип': 'мини-печь', 'Модель': 'Kraft Technology TCH-MO 6011 RKGL'}
# {'source': '/content/data/multivarka-midea-mpc-6033-serebristyj.txt', 'Источник': 'https://www.dns-shop.ru/product/c6d3abf1dd203333/multivarka-midea-mpc-6033-serebristyj/characteristics/', 'Тип': 'мультиварка', 'Модель': 'Midea MPC-6033'}
# {'source': '/content/data/kondicioner-nastennyj-split-sistema-lg-tc09gqr-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/045c1ff6a0e52eb0/kondicioner-nastennyj-split-sistema-lg-tc09gqr-belyj/characteristics/', 'Тип': 'кондиционер', 'Модель': 'LG TC09GQR'}
# {'source': '/content/data/holodilnik-s-morozilnikom--birusa-118-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/eee593c026063330/holodilnik-s-morozilnikom--birusa-118-belyj/characteristics/', 'Тип': 'холодильник полноразмерный с морозильником', 'Модель': 'Бирюса 118'}
# {'source': '/content/data/ventilator-midea-fs4071--cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/fdcb213f2572f697/ventilator-midea-fs4071--cernyj/characteristics/', 'Тип': 'вентилятор', 'Модель': 'Midea FS4071'}
# {'source': '/content/data/pylesos-tefal-x-trem-cyclonic-max-tw7b33ea-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/4f14321f584dd9cb/pylesos-tefal-x-trem-cyclonic-max-tw7b33ea-cernyj/characteristics/', 'Тип': 'пылесос', 'Модель': 'Tefal X-Trem Cyclonic Max TW7B33EA'}
# {'source': '/content/data/ventilator-reoka-rktbf-1500--serebristyj.txt', 'Источник': 'https://www.dns-shop.ru/product/f9134d01735201c3/ventilator-reoka-rktbf-1500--serebristyj/characteristics/', 'Тип': 'вентилятор', 'Модель': 'Reoka RKTBF-1500'}
# ...
# {'source': '/content/data/masorubka-elektriceskaa-polaris-pmg-2079al-silent-serebristyj.txt', 'Источник': 'https://www.dns-shop.ru/product/4d54be93d3062ff2/masorubka-elektriceskaa-polaris-pmg-2079al-silent-serebristyj/characteristics/', 'Тип': 'мясорубка электрическая', 'Модель': 'Polaris PMG 2079AL Silent'}
# {'source': '/content/data/masorubka-elektriceskaa-polaris-pmg-2050-rus-fioletovyj.txt', 'Источник': 'https://www.dns-shop.ru/product/1f7ed248ac1d3332/masorubka-elektriceskaa-polaris-pmg-2050-rus-fioletovyj/characteristics/', 'Тип': 'мясорубка электрическая', 'Модель': 'Polaris PMG 2050 RUS'}
# {'source': '/content/data/kondicioner-nastennyj-split-sistema-lg-s09eqr-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/c1ce795543601b80/kondicioner-nastennyj-split-sistema-lg-s09eqr-belyj/characteristics/', 'Тип': 'кондиционер', 'Модель': 'LG S09EQR'}
# {'source': '/content/data/pylesos-thomas-twin-puma-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/505ba1867dc31b80/pylesos-thomas-twin-puma-cernyj/characteristics/', 'Тип': 'пылесос', 'Модель': 'Thomas Twin Puma'}
# {'source': '/content/data/multivarka-midea-mpc-6032-serebristyj.txt', 'Источник': 'https://www.dns-shop.ru/product/f1347df71d943333/multivarka-midea-mpc-6032-serebristyj/characteristics/', 'Тип': 'мультиварка', 'Модель': 'Midea MPC-6032'}
# {'source': '/content/data/ventilator-timberk-t-sf1201--cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/55e9f8f3ad469046/ventilator-timberk-t-sf1201--cernyj/characteristics/', 'Тип': 'вентилятор', 'Модель': 'Timberk T-SF1201'}
# {'source': '/content/data/ventilator-lex-lxfc8383--serebristyj.txt', 'Источник': 'https://www.dns-shop.ru/product/2506f6b03a2ed172/ventilator-lex-lxfc8383--serebristyj/characteristics/', 'Тип': 'вентилятор', 'Модель': 'LEX LXFC8383'}
# {'source': '/content/data/masorubka-elektriceskaa-kitfort-kt-2103-serebristyj.txt', 'Источник': 'https://www.dns-shop.ru/product/67c1723219433330/masorubka-elektriceskaa-kitfort-kt-2103-serebristyj/characteristics/', 'Тип': 'мясорубка электрическая', 'Модель': 'Kitfort KT-2103'}
# {'source': '/content/data/kombinirovannaa-plita-darina-1-b-3321-w-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/db22caf8ca46d763/kombinirovannaa-plita-darina-1-b-3321-w-belyj/characteristics/', 'Тип': 'плита комбинированная', 'Модель': 'DARINA 1 B 3321 W'}
# {'source': '/content/data/ventilator-brayer-br4950--belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/5ebeb55e83083333/ventilator-brayer-br4950--belyj/characteristics/', 'Тип': 'вентилятор', 'Модель': 'BRAYER BR4950'}
# {'source': '/content/data/pylesos-delta-lux-de-3501-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/2561e2398ef62ff4/pylesos-delta-lux-de-3501-cernyj/characteristics/', 'Тип': 'пылесос', 'Модель': 'Delta LUX DE-3501'}
# {'source': '/content/data/kombinirovannaa-plita-darina-1313-w-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/ccf76844a3a61b80/kombinirovannaa-plita-darina-1313-w-belyj/characteristics/', 'Тип': 'плита комбинированная', 'Модель': 'DARINA 1313 W'}
# {'source': '/content/data/mini-pec-centek-ct-1532-46-convection-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/a47357108af33330/mini-pec-centek-ct-1532-46-convection-cernyj/characteristics/', 'Тип': 'мини-печь', 'Модель': 'Centek CT-1532-46 Convection'}
# {'source': '/content/data/kombinirovannaa-plita-darina-2313-h-seryj.txt', 'Источник': 'https://www.dns-shop.ru/product/fb63eac2a3a61b80/kombinirovannaa-plita-darina-2313-h-seryj/characteristics/', 'Тип': 'плита комбинированная', 'Модель': 'DARINA 2313 Х'}
# {'source': '/content/data/multivarka-aceline-amc553-serebristyj.txt', 'Источник': 'https://www.dns-shop.ru/product/42a9cdcba753ed20/multivarka-aceline-amc553-serebristyj/characteristics/', 'Тип': 'мультиварка', 'Модель': 'Aceline AMC553'}
# {'source': '/content/data/mini-pec-dexp-eo-d1635-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/3d4ec4d9569c6fe6/mini-pec-dexp-eo-d1635-cernyj/characteristics/', 'Тип': 'мини-печь', 'Модель': 'DEXP EO-D1635'}
# {'source': '/content/data/kondicioner-nastennyj-split-sistema-tcl-breezein-12-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/33d0ad8b5846ed20/kondicioner-nastennyj-split-sistema-tcl-breezein-12-belyj/characteristics/', 'Тип': 'кондиционер', 'Модель': 'TCL BREEZEIN 12'}
# {'source': '/content/data/pylesos-endever-skyclean-vc-560-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/a48496b9e1293330/pylesos-endever-skyclean-vc-560-cernyj/characteristics/', 'Тип': 'пылесос', 'Модель': 'Endever Skyclean VC-560'}
# {'source': '/content/data/ventilator-brayer-4958br-wh--belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/2fcb2db8a3402ff4/ventilator-brayer-4958br-wh--belyj/characteristics/', 'Тип': 'вентилятор', 'Модель': 'BRAYER 4958BR-WH'}
# {'source': '/content/data/kombinirovannaa-plita-gefest-pge-6302-04-0046-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/3eaaf3fc0202f2e8/kombinirovannaa-plita-gefest-pge-6302-04-0046-cernyj/characteristics/', 'Тип': 'плита комбинированная', 'Модель': 'Gefest ПГЭ 6302-04 0046'}
# {'source': '/content/data/ventilator-electrolux-etf-115w--belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/69e8f39f46aecc5f/ventilator-electrolux-etf-115w--belyj/characteristics/', 'Тип': 'вентилятор', 'Модель': 'Electrolux ETF-115W'}
# {'source': '/content/data/mini-pec-dexp-vn-3400-bl-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/dea9ec53f726ed20/mini-pec-dexp-vn-3400-bl-cernyj/characteristics/', 'Тип': 'мини-печь', 'Модель': 'DEXP VN-3400 BL'}
# {'source': '/content/data/mini-pec-hyundai-mio-hy080-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/7dfdad41fc41ca51/mini-pec-hyundai-mio-hy080-cernyj/characteristics/', 'Тип': 'мини-печь', 'Модель': 'Hyundai MIO-HY080'}
# {'source': '/content/data/masorubka-elektriceskaa-gorenje-mg1601w-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/a16131cfeddc3432/masorubka-elektriceskaa-gorenje-mg1601w-belyj/characteristics/', 'Тип': 'мясорубка электрическая', 'Модель': 'Gorenje MG1601W'}
# {'source': '/content/data/mini-pec-centek-ct-1530-36-convection-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/a473570a8af33330/mini-pec-centek-ct-1530-36-convection-cernyj/characteristics/', 'Тип': 'мини-печь', 'Модель': 'Centek CT-1530-36 Convection'}
# {'source': '/content/data/gazovaa-plita-darina-g-4001-at-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/04c985ef9e2f1b80/gazovaa-plita-darina-g-4001-at-cernyj/characteristics/', 'Тип': 'газовая плита', 'Модель': 'DARINA G 4001 At'}
# {'source': '/content/data/kombinirovannaa-plita-gorenje-gk5c41sf-seryj.txt', 'Источник': 'https://www.dns-shop.ru/product/f9b1adea2f61a77f/kombinirovannaa-plita-gorenje-gk5c41sf-seryj/characteristics/', 'Тип': 'плита комбинированная', 'Модель': 'Gorenje GK5C41SF'}
# {'source': '/content/data/ventilator-reoka-rksf-c2400--cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/47cf0afdc76acce1/ventilator-reoka-rksf-c2400--cernyj/characteristics/', 'Тип': 'вентилятор', 'Модель': 'Reoka RKSF-C2400'}
# {'source': '/content/data/gazovaa-plita-gefest-gs-1206-b-koricnevyj.txt', 'Источник': 'https://www.dns-shop.ru/product/c2e84e8454133330/gazovaa-plita-gefest-gs-1206-b-koricnevyj/characteristics/', 'Тип': 'газовая плита', 'Модель': 'Gefest GS 1206 B'}
# {'source': '/content/data/mini-pec-aceline-vn-3000-hp-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/cd2dff32f727ed20/mini-pec-aceline-vn-3000-hp-cernyj/characteristics/', 'Тип': 'мини-печь', 'Модель': 'Aceline VN-3000 HP'}
# {'source': '/content/data/mini-pec-reoka-rkbm-m618-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/6d2e31b7f880ed20/mini-pec-reoka-rkbm-m618-cernyj/characteristics/', 'Тип': 'мини-печь', 'Модель': 'Reoka RKBM-M618'}
# {'source': '/content/data/holodilnik-kompaktnyj--aceline-s201amg-koricnevyj.txt', 'Источник': 'https://www.dns-shop.ru/product/5f03a4bb8805ed20/holodilnik-kompaktnyj--aceline-s201amg-koricnevyj/characteristics/', 'Тип': 'холодильник компактный', 'Модель': 'Aceline S201AMG'}
# {'source': '/content/data/pylesos-dexp-c-2000-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/11a8c9a3e3efed20/pylesos-dexp-c-2000-cernyj/characteristics/', 'Тип': 'пылесос', 'Модель': 'DEXP C-2000'}
# {'source': '/content/data/gazovaa-plita-gefest-5300-02-0046-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/fc55ce22a4993330/gazovaa-plita-gefest-5300-02-0046-cernyj/characteristics/', 'Тип': 'газовая плита', 'Модель': 'Gefest 5300-02 0046'}
# {'source': '/content/data/multivarka-redmond-mc103-serebristyj.txt', 'Источник': 'https://www.dns-shop.ru/product/59c36ca78e55ed20/multivarka-redmond-mc103-serebristyj/characteristics/', 'Тип': 'мультиварка', 'Модель': 'Redmond MC103'}
# {'source': '/content/data/pylesos-panasonic-mc-cg715k149-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/9ee53b3139e93333/pylesos-panasonic-mc-cg715k149-cernyj/characteristics/', 'Тип': 'пылесос', 'Модель': 'Panasonic MC-CG715K149'}
# {'source': '/content/data/gazovaa-plita-darina-b1-3g07-w-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/cead78efb6492ff4/gazovaa-plita-darina-b1-3g07-w-belyj/characteristics/', 'Тип': 'газовая плита', 'Модель': 'DARINA B1 3G07 W'}
# {'source': '/content/data/multivarka-skorovarka-midea-mpc-6037-serebristyj.txt', 'Источник': 'https://www.dns-shop.ru/product/733fbd0dc0592ff4/multivarka-skorovarka-midea-mpc-6037-serebristyj/characteristics/', 'Тип': 'мультиварка-скороварка', 'Модель': 'Midea MPC-6037'}
# {'source': '/content/data/gazovaa-plita-gefest-gs-6515b1-gc-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/7a5566fdb1264d70/gazovaa-plita-gefest-gs-6515b1-gc-cernyj/characteristics/', 'Тип': 'газовая плита', 'Модель': 'Gefest GS 6515B1 GC'}
# {'source': '/content/data/masorubka-elektriceskaa-dexp-mgl-2200s-serebristyj.txt', 'Источник': 'https://www.dns-shop.ru/product/b477489566521b80/masorubka-elektriceskaa-dexp-mgl-2200s-serebristyj/characteristics/', 'Тип': 'мясорубка электрическая', 'Модель': 'DEXP MGL-2200S'}
# {'source': '/content/data/kombinirovannaa-plita-darina-3311-w-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/821f7e3c25c43330/kombinirovannaa-plita-darina-3311-w-belyj/characteristics/', 'Тип': 'плита комбинированная', 'Модель': 'DARINA 3311 W'}
# {'source': '/content/data/gazovaa-plita-gefest-gs-3208-w-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/fe0527dc54123330/gazovaa-plita-gefest-gs-3208-w-belyj/characteristics/', 'Тип': 'газовая плита', 'Модель': 'Gefest GS 3208 W'}
# {'source': '/content/data/ventilator-electrolux-efb-1215b--cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/e827006c3386a42d/ventilator-electrolux-efb-1215b--cernyj/characteristics/', 'Тип': 'вентилятор', 'Модель': 'Electrolux EFB-1215b'}
# {'source': '/content/data/multivarka-skorovarka-dexp-dpc-105-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/1673f693ab400884/multivarka-skorovarka-dexp-dpc-105-cernyj/characteristics/', 'Тип': 'мультиварка-скороварка', 'Модель': 'DEXP DPC-105'}
# {'source': '/content/data/gazovaa-plita-gefest-gs-3208b-gc-koricnevyj.txt', 'Источник': 'https://www.dns-shop.ru/product/ccb887091ddf40be/gazovaa-plita-gefest-gs-3208b-gc-koricnevyj/characteristics/', 'Тип': 'газовая плита', 'Модель': 'Gefest GS 3208B GC'}
# {'source': '/content/data/gazovaa-plita-gefest-gs-1207-w-gc-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/3ee2917cfcc8166e/gazovaa-plita-gefest-gs-1207-w-gc-belyj/characteristics/', 'Тип': 'газовая плита', 'Модель': 'Gefest GS 1207 W GC'}
# {'source': '/content/data/kombinirovannaa-plita-gefest-pge-6302-03-0046-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/225be5b5db16b44a/kombinirovannaa-plita-gefest-pge-6302-03-0046-cernyj/characteristics/', 'Тип': 'плита комбинированная', 'Модель': 'Gefest ПГЭ 6302-03 0046'}
# {'source': '/content/data/mini-pec-centek-ct-1530-36-convection-bezevyj.txt', 'Источник': 'https://www.dns-shop.ru/product/6d81e885093e2ff2/mini-pec-centek-ct-1530-36-convection-bezevyj/characteristics/', 'Тип': 'мини-печь', 'Модель': 'Centek CT-1530-36 Convection'}
# {'source': '/content/data/mini-pec-dexp-vn-3400-gr-seryj.txt', 'Источник': 'https://www.dns-shop.ru/product/ecc4995cfa09ed20/mini-pec-dexp-vn-3400-gr-seryj/characteristics/', 'Тип': 'мини-печь', 'Модель': 'DEXP VN-3400 GR'}
# {'source': '/content/data/gazovaa-plita-gefest-gs-3206-w-gc-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/142ce42cdf4c3a30/gazovaa-plita-gefest-gs-3206-w-gc-belyj/characteristics/', 'Тип': 'газовая плита', 'Модель': 'Gefest GS 3206 W GC'}
# {'source': '/content/data/masorubka-elektriceskaa-polaris-pmg-2546-serebristyj.txt', 'Источник': 'https://www.dns-shop.ru/product/33d2d79eeb9e1b80/masorubka-elektriceskaa-polaris-pmg-2546-serebristyj/characteristics/', 'Тип': 'мясорубка электрическая', 'Модель': 'Polaris PMG 2546'}
# {'source': '/content/data/masorubka-elektriceskaa-redmond-rmg-1246-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/ba94596a10f6ff7a/masorubka-elektriceskaa-redmond-rmg-1246-cernyj/characteristics/', 'Тип': 'мясорубка электрическая', 'Модель': 'Redmond RMG-1246'}
# {'source': '/content/data/ventilator-solove-mini-handheld-fan-f6--belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/7e563af41c2c9166/ventilator-solove-mini-handheld-fan-f6--belyj/characteristics/', 'Тип': 'вентилятор', 'Модель': 'SOLOVE Mini Handheld Fan F6'}
# {'source': '/content/data/ventilator-scarlett-sc-df111s01--belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/466bdbf6a94a8a5a/ventilator-scarlett-sc-df111s01--belyj/characteristics/', 'Тип': 'вентилятор', 'Модель': 'Scarlett SC-DF111S01'}
# {'source': '/content/data/mini-pec-kraft-kfc-mo-200-hbl-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/2177373971142800/mini-pec-kraft-kfc-mo-200-hbl-cernyj/characteristics/', 'Тип': 'мини-печь', 'Модель': 'Kraft KFC-MO 200 HBL'}
# {'source': '/content/data/pylesos-jvc-jh-vc405-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/ba8401208a012ff4/pylesos-jvc-jh-vc405-cernyj/characteristics/', 'Тип': 'пылесос', 'Модель': 'JVC JH-VC405'}
# {'source': '/content/data/ventilator-brayer-4958br-bk--cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/2fcb2db6a3402ff4/ventilator-brayer-4958br-bk--cernyj/characteristics/', 'Тип': 'вентилятор', 'Модель': 'BRAYER 4958BR-BK'}
# {'source': '/content/data/masorubka-elektriceskaa-polaris-pmg-1873-rus-seryj.txt', 'Источник': 'https://www.dns-shop.ru/product/8c8b42e3d5692ff2/masorubka-elektriceskaa-polaris-pmg-1873-rus-seryj/characteristics/', 'Тип': 'мясорубка электрическая', 'Модель': 'Polaris PMG 1873 RUS'}
# {'source': '/content/data/multivarka-redmond-rmc-m291-serebristyj.txt', 'Источник': 'https://www.dns-shop.ru/product/a0cab886aedd3332/multivarka-redmond-rmc-m291-serebristyj/characteristics/', 'Тип': 'мультиварка', 'Модель': 'Redmond RMC-M291'}
# {'source': '/content/data/gazovaa-plita-gefest-gs-3206-b-koricnevyj.txt', 'Источник': 'https://www.dns-shop.ru/product/790607fa6d1f3330/gazovaa-plita-gefest-gs-3206-b-koricnevyj/characteristics/', 'Тип': 'газовая плита', 'Модель': 'Gefest GS 3206 B'}
# {'source': '/content/data/masorubka-elektriceskaa-redmond-rmg-1205-8-belyj.txt', 'Источник': 'https://www.dns-shop.ru/product/8a43e2b357741b80/masorubka-elektriceskaa-redmond-rmg-1205-8-belyj/characteristics/', 'Тип': 'мясорубка электрическая', 'Модель': 'Redmond RMG-1205-8'}
# {'source': '/content/data/pylesos-thomas-twin-sigma-aquafilter-cernyj.txt', 'Источник': 'https://www.dns-shop.ru/product/3ddac4d7a13c2ff4/pylesos-thomas-twin-sigma-aquafilter-cernyj/characteristics/', 'Тип': 'пылесос', 'Модель': 'Thomas Twin Sigma Aquafilter'}
# {'холодильник полноразмерный с морозильником', 'мультиварка', 'мини-печь', 'пылесос', 'мультиварка-скороварка', 'холодильник компактный', 'плита комбинированная', 'вентилятор', 'газовая плита', 'кондиционер', 'мясорубка электрическая'}

# %%
# !zip -r my_archive.zip chroma_db
# Out:
#   adding: chroma_db/ (stored 0%)
#   adding: chroma_db/d39736d6-bf89-478b-b83d-92aa1a2ee1cb/ (stored 0%)
#   adding: chroma_db/d39736d6-bf89-478b-b83d-92aa1a2ee1cb/index_metadata.pickle (deflated 43%)
#   adding: chroma_db/d39736d6-bf89-478b-b83d-92aa1a2ee1cb/header.bin (deflated 56%)
#   adding: chroma_db/d39736d6-bf89-478b-b83d-92aa1a2ee1cb/data_level0.bin (deflated 10%)
#   adding: chroma_db/d39736d6-bf89-478b-b83d-92aa1a2ee1cb/link_lists.bin (deflated 83%)
#   adding: chroma_db/d39736d6-bf89-478b-b83d-92aa1a2ee1cb/length.bin (deflated 90%)
#   adding: chroma_db/chroma.sqlite3 (deflated 93%)

# %%
# !unzip "my_archive (5).zip" -d chroma_db
# Out:
# Archive:  my_archive (5).zip
#    creating: chroma_db/chroma_db1/
#   inflating: chroma_db/chroma_db1/chroma.sqlite3
#    creating: chroma_db/chroma_db1/72068996-67be-4503-8250-d70535372315/
#   inflating: chroma_db/chroma_db1/72068996-67be-4503-8250-d70535372315/index_metadata.pickle
#   inflating: chroma_db/chroma_db1/72068996-67be-4503-8250-d70535372315/header.bin
#   inflating: chroma_db/chroma_db1/72068996-67be-4503-8250-d70535372315/data_level0.bin
#   inflating: chroma_db/chroma_db1/72068996-67be-4503-8250-d70535372315/link_lists.bin
#   inflating: chroma_db/chroma_db1/72068996-67be-4503-8250-d70535372315/length.bin

# %%
from langchain_gigachat import GigaChat
import os
import torch
from langchain.document_loaders import TextLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import Chroma
from langchain_groq import ChatGroq
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate
from dotenv import load_dotenv
import pandas as pd
import re
from typing import List
from langchain_core.output_parsers import StrOutputParser
from google.colab import userdata
from IPython.display import display, Markdown
from collections import Counter
import time
creds = userdata.get('GigaChatKey')

# llm = GigaChat(
#         temperature=0.2,
#         max_tokens=700,
#         verify_ssl_certs=False,
#         credentials=creds,
#         scope='GIGACHAT_API_PERS',
#         model="GigaChat-Max"
#     )

llm = ChatGroq(
        groq_api_key=GROQ_API_KEY,
        model_name="llama3-70b-8192",
        temperature=0.5,
        max_tokens=1400,
    )


get_type_prompt = PromptTemplate(
    template = """
    Запрос пользователя: {msg}

    Определи, какие типы товаров из доступных подойдут к этому запросу пользователя.
     В ответе пиши ТОЛЬКО типы товаров в точности как я дал тебе, другие типы писать не разрешается.
     Пиши в строчку через запятую. Если нет подходящих товаров, то напиши "такой техники нет".
     ПИШИ ТОЛЬКО ПОДХОДЯЩИЕ ПОД ЗАПРОС ТИПЫ ТОВАРОВ. НЕ ПИШИ БОЛЕЕ 3 ТИПОВ.
     Доступные типы товаров: {types}
     Подходящие типы товаров:
    """,
    input_variables = ['msg','types']
)

get_type_chain = get_type_prompt|llm|StrOutputParser()
#проверим как оно работает
##print(get_type_chain.invoke({'msg':"нужен слон","types":types}))
##print(get_type_chain.invoke({'msg':"нужна штука которая делает холод короче и туда еще еду можно пихать и чтоб большая и крутая","types":types}))
#добавим получение характеристик из 'шаблона'
msg = "хочу купить слона"
searched_types = get_type_chain.invoke({'msg':msg,"types":', '.join(types)}).split(', ')
#такие типы подходящих товаров выходят
print(searched_types)
#сюда 'шаблоны' (примеры документа с товаром) пишем
product_examples = []
#накидываем шаблоны
for x in searched_types:

  if len(vectorstore.get(where={"Тип":x},limit=1)['ids']):
    filepath = vectorstore.get(where={"Тип":x},limit=1)['metadatas'][0]['source']
  else:
    continue
  with open(filepath,'r') as f:
    product_examples.append(f.read())

product_examples=["Пример "+str(x)+":"+y+'\n\n' for x,y in enumerate(product_examples)]
print(product_examples)
get_chars_prompt = PromptTemplate(
    template="""
    Пожелания пользователя:
    {msg}

    По пожеланиям определи, какие характеристики важны для пользователя.
    Напиши эти характеристики в формате название1: значение1\n название2: значение2\n и т.д.
    Пиши ТОЛЬКО ПАРЫ. Старайся угадать примерные ЧИСЛЕННЫЕ (там где они могут быть численными) значения.
     названия характеристик бери из данных тебе примеров, строго соблюдай их.
     Значения ты должен приблизительно оценить исходя из пожеланий пользователя.
      Пиши конкретные значения, без уточнений, сносок. Если характеристика не относится к пожеланиям пользователя то ты ее не пишешь.


    Примеры характеристик (значения могут не соответствовать пожеланиям):
    {examples}

    """,
    input_variables = ['msg','examples']
)

get_chars_chain = get_chars_prompt|llm|StrOutputParser()
#работает?
chars = get_chars_chain.invoke({'msg':msg,'examples':product_examples}).split('\n')
print(chars)

#добавим сообщение пользователя для поиска по описанию
chars.append(msg)
#ищем по этим характеристикам
filter = {"Тип": {"$in": searched_types}}
suiting_models = []
for char in chars:
  res = vectorstore.similarity_search(char,filter=filter,k=10)
  models = {x.metadata['Модель'] for x in res}
  suiting_models+=models
  print(suiting_models)

chosen_models=Counter(suiting_models).most_common(4)
print(Counter(suiting_models))
get_recomendations_template=PromptTemplate(
    template="""
    Пользователь хочет найти товар подходящий под его описание. СТРОГО следуй такому плану ответа:
    1. Опиши каждый подходящий запросу пользователя товар, дай его необходимые характеристики и немного дополнительных, опиши его плюсы и минусы (ОТНОСИТЕЛЬНО ЗАПРОСА ПОЛЬЗОВАТЕЛЯ), причины, по которым ты выбрал этот товар как подходящий.
    2. Основываясь на своих объективных рассуждениях (на основе характеристик подходящих товаров), сравни подходящие товары между собой (ОТНОСИТЕЛЬНО ЗАПРОСА ПОЛЬЗОВАТЕЛЯ), дай пользователю рекомендации.
    3. ЕСЛИ ТОВАР НЕ ПОДХОДИТ ПОД ЗАПРОС ПОЛЬЗОВАТЕЛЯ, ТЫ ЕГО НЕ ПИШЕШЬ.
    Запрос пользователя: {msg}

    Характеристики товаров: {products}

    Подходящие товары, их описания с плюсами и минусами, их сравние и рекомендации на русском:
    """,
    input_variables=['msg','products']
)

get_recomendations_chain = get_recomendations_template|llm|StrOutputParser()

products = []
print(chosen_models)
for x in chosen_models:
  filepath = vectorstore.get(where={"Модель":x[0]},limit=1)['metadatas'][0]['source']
  with open(filepath,'r') as f:
    products.append(f'Модель - {x}\n'+f.read())
products = '\n'.join(products)

display(Markdown(get_recomendations_chain.invoke({'msg':msg,'products':products})))
# Out:
# ['Такой техники нет.']
# []
# ['Вот какие характеристики важны для пользователя:', '', 'Вес: 5000 кг', 'Высота: 3 м', 'Цена: 1000000 руб', 'Возраст: 5 лет', 'Пол: мужской', 'Порода: индийский слон']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# Counter()
# []
# **Подходящие товары**
#
# 1. **Фигурка слона из керамики**
# 	* Характеристики: материал - керамика, размер - 15 см, вес - 0,5 кг, цвет - белый
# 	* Плюсы: декоративный, безопасный, легко очищается
# 	* Минусы: не может быть использован как игрушка, может быть хрупким
# 	* Причина выбора: это декоративный элемент, который может быть использован для украшения интерьера, и он соответствует запросу пользователя о покупке слона
# 2. **Слон из плюша**
# 	* Характеристики: материал - плюш, размер - 30 см, вес - 0,2 кг, цвет - серый
# 	* Плюсы: мягкий, приятный на ощупь, может быть использован как игрушка
# 	* Минусы: может потерять форму, не подходит для украшения интерьера
# 	* Причина выбора: это мягкая игрушка, которая может быть использована для игры или как декоративный элемент, и она соответствует запросу пользователя о покупке слона
#
# **Сравнение товаров**
#
# Оба товара соответствуют запросу пользователя о покупке слона, но они имеют разные характеристики и предназначения. Фигурка слона из керамики является декоративным элементом, который может быть использован для украшения интерьера, а слон из плюша является мягкой игрушкой, которая может быть использована для игры или как декоративный элемент.
#
# **Рекомендации**
#
# Если вы ищете декоративный элемент для украшения интерьера, то рекомендуется выбрать фигурку слона из керамики. Если вы ищете мягкую игрушку для игры или как декоративный элемент, то рекомендуется выбрать слона из плюша.

# %%
from langchain.tools import Tool
from collections import Counter
from langgraph.checkpoint.memory import MemorySaver
from langgraph.prebuilt.chat_agent_executor import AgentState
import langgraph
import os
from langchain.agents import AgentExecutor, create_react_agent
import os
from dotenv import load_dotenv
from typing import List, Optional
from operator import itemgetter
import time

llm = ChatGroq(
        groq_api_key=GROQ_API_KEY,
        model_name="llama3-70b-8192",
        temperature=0.5,
        max_tokens=500,
    )

llm2 = GigaChat(
        temperature=0.2,
        max_tokens=700,
        verify_ssl_certs=False,
        credentials=creds,
        scope='GIGACHAT_API_PERS',
   )

get_recomendations_template=PromptTemplate(
    template="""
    Пользователь хочет найти товар подходящий под его описание. СТРОГО следуй такому плану ответа:
    1. Опиши каждый подходящий запросу пользователя товар, дай его необходимые характеристики и немного дополнительных, опиши его плюсы и минусы (ОТНОСИТЕЛЬНО ЗАПРОСА ПОЛЬЗОВАТЕЛЯ), причины, по которым ты выбрал этот товар как подходящий.
    2. Основываясь на своих объективных рассуждениях (на основе характеристик подходящих товаров), сравни подходящие товары между собой (ОТНОСИТЕЛЬНО ЗАПРОСА ПОЛЬЗОВАТЕЛЯ), дай пользователю рекомендации.
    3. ЕСЛИ ТОВАР НЕ ПОДХОДИТ ПОД ЗАПРОС ПОЛЬЗОВАТЕЛЯ, ТЫ ЕГО НЕ ПИШЕШЬ.
    Запрос пользователя: {msg}

    Характеристики товаров: {products}

    Подходящие товары, их описания с плюсами и минусами, их сравние и рекомендации на русском:
    """,
    input_variables=['msg','products']
)

get_type_prompt = PromptTemplate(
    template = """
    Запрос пользователя: {msg}

    Определи, какие типы товаров из доступных подойдут к этому запросу пользователя.
     В ответе пиши ТОЛЬКО типы товаров в точности как я дал тебе, другие типы писать не разрешается.
     Пиши в строчку через запятую. Если нет подходящих товаров, то напиши "нет".
     ПИШИ ТОЛЬКО ПОДХОДЯЩИЕ ПОД ЗАПРОС ТИПЫ ТОВАРОВ. НЕ ПИШИ БОЛЕЕ 3 ТИПОВ.
     Доступные типы товаров: {types}
     Подходящие типы товаров:
    """,
    input_variables = ['msg','types']
)

get_chars_prompt = PromptTemplate(
    template="""
    Пожелания пользователя:
    {msg}

    По пожеланиям определи, какие характеристики важны для пользователя.
    Напиши эти характеристики в формате название1: значение1\n название2: значение2\n и т.д.
    Пиши ТОЛЬКО ПАРЫ. Старайся угадать примерные ЧИСЛЕННЫЕ (там где они могут быть численными) значения.
     названия характеристик бери из данных тебе примеров, строго соблюдай их.
     Значения ты должен приблизительно оценить исходя из пожеланий пользователя.
      Пиши конкретные значения, без уточнений, сносок. Если характеристика не относится к пожеланиям пользователя то ты ее не пишешь.


    Примеры характеристик (значения могут не соответствовать пожеланиям):
    {examples}

    """,
    input_variables = ['msg','examples']
)

get_type_chain = get_type_prompt|llm|StrOutputParser()
get_chars_chain = get_chars_prompt|llm|StrOutputParser()
get_recomendations_chain = get_recomendations_template|llm|StrOutputParser()

def get_suiting_product_data(query:str)->str:
  searched_types = get_type_chain.invoke({'msg':query,"types":', '.join(types)}).split(', ')
  #проверка на наличие
  if not len(searched_types) or searched_types[0]=='нет':
    return f"Кажется, нет типов товаров, подходящих под данный запрос. Доступные типы товаров : {', '.join(types)}"
  #сюда 'шаблоны' (примеры документа с товаром) пишем
  product_examples = []
  #накидываем шаблоны
  for x in searched_types:
    if len(vectorstore.get(where={"Тип":x},limit=1)['ids']):
      filepath = vectorstore.get(where={"Тип":x},limit=1)['metadatas'][0]['source']
    else:
      continue
    with open(filepath,'r') as f:
      product_examples.append(f.read())
  #форматируем в роботочитаемый текст
  product_examples=["Пример "+str(x)+":"+y+'\n\n' for x,y in enumerate(product_examples)]
  #теперь найдем примерные характеристики товара по шаблону
  chars = get_chars_chain.invoke({'msg':query,'examples':product_examples}).split('\n')
  #добавим сообщение пользователя для поиска по описанию
  chars.append(query)
  #ищем по этим характеристикам
  filter = {"Тип": {"$in": searched_types}}
  suiting_models = []
  for char in chars:
    res = vectorstore.similarity_search(char,filter=filter,k=10)
    models = {x.metadata['Модель'] for x in res}
    suiting_models+=models
  #тут мы короче сделали запрос по каждой характеристике, посчитали кол-во вхождений одной и той же модели
  #(кол-во попадающих под запрос характеристик)
  products =[]
  chosen_models=[x[0] for x in Counter(suiting_models).most_common(3)]
  print(chosen_models)
  for x in chosen_models:
    filepath = vectorstore.get(where={"Модель":x},limit=1)['metadatas'][0]['source']
    with open(filepath,'r') as f:
      products.append(f'Модель - {x}\n'+f.read())
  products = '\n'.join(products)
  return products

def get_product_by_model(model:str)->str:
  filter = {"Модель": model}
  if len(vectorstore.get(where={"Модель":model},limit=1)['metadatas']):
    filepath = vectorstore.get(where={"Модель":model},limit=1)['metadatas'][0]['source']
    with open(filepath,'r') as f:
      return f'Точное совпадение, Модель - {x}\n'+f.read()
  else:
    results = [x.metadata['Модель'] for x in vectorstore.similarity_search(f'Модель: {model}',k=5)]
    print(results)
    return "Не найдено точное совпадение, возможно данные отрывки текста смогут помочь?\n"+', '.join(results)




# Создаем объекты инструментов
tools = [
    Tool(
        name="GetSuitingProducts",
        func=lambda query: get_suiting_product_data(query),
        description="Принимает на вход ЗАПРОС (СТРОКУ). Находит подходящие по запросу товары. Указание конкретных характеристик повысит точность."
    ),
        Tool(
        name="GetProductByModel",
        func=lambda model: get_product_by_model(model),
        description="На вход принимает СТРОКУ с названием модели бытовой техники. Возвращает (СТРОКУ) характеристики техники в случае точного совпадения. Иначе вернет список похожишь значений"
    )
]

# Промпт для агента
prefix = """
Ты — ассистент по подбору бытовой техники. Твоя задача:
1. Найди информацию, связанную с запросом пользователя. Или попроси пользователя уточнить запрос.
2. Выбери подходящую под запрос пользователя технику. Не подходящую не показывай
3. Опиши характеристики подходящей техники. Ее плюсы и минусы, дай рекомендацию пользователю на основе данных.
4(опционально). Уточни информацию, если пользователь попросит.
функция GetSuitingProducts - принимает запрос (query) для поиска данных. Ты можешь уточнять запрос по просьбе пользователя, старайся использовать эту функцию реже.
функция GetProductByModel - принимает модель техники. Возвращает точное описание модели техники при точном совпадении иначе - список похожих моделей.
 Используй GetProductByModel для уточнения характеристик ранее упомянутых тобою моделей техники, если потребуется.
"""

#agent.run('хочу пылесос')
memory = MemorySaver()
agent_executor = langgraph.prebuilt.chat_agent_executor.create_react_agent(llm, tools, checkpointer=memory,debug=False,prompt=prefix)
config = {"configurable": {"thread_id": "abc123"}}

result = agent_executor.invoke({
    "messages": [{"role": "user", "content": "Хочу пылесос"}]
}, config)
print("запрос 1: Хочу пылесос")
display(Markdown(result["messages"][-1].content))
time.sleep(60)
result = agent_executor.invoke({
    "messages": [{"role": "user", "content": "какой из представленных тобою ранее пылесосов по твоему мнению лучший?"}]
}, config)
print("запрос 2: какой из представленных тобою ранее пылесосов по твоему мнению лучший?")
display(Markdown(result["messages"][-1].content))
time.sleep(60)
result = agent_executor.invoke({
    "messages": [{"role": "user", "content": "Среди упомянутых тобою пылесосов найди тот, у которого наибольшая длина провода"}]
}, config)
print("запрос 3: Среди упомянутых тобою пылесосов найди тот, у которого наибольшая длина провода")
display(Markdown(result["messages"][-1].content))
# Out:
# ['Centek CT-2519', 'Bosch BGBS2BA1P', 'Delta LUX DE-3501']
# запрос 1: Хочу пылесос
# Вот характеристики пылесоса Centek CT-2519, который может быть подходящим вариантом для вас. Он имеет фильтр тонкой очистки, который эффективно удаляет аллергены и загрязнения из воздуха. Емкость пылесборника составляет 4 л, а регулятор мощности расположен на корпусе для удобства пользователей. Телескопическая труба всасывания легко подстраивается под рост пользователя, а технология защиты от перегрева не позволяет прибору внезапно выйти из строя. Комплект насадок позволяет легко удалять загрязнения из труднодоступных мест.
#
# В целом, это хороший вариант для сухой уборки помещений. Если у вас есть вопросы или вам нужно больше информации, пожалуйста, уточните.
# запрос 2: какой из представленных тобою ранее пылесосов по твоему мнению лучший?
# Сравнивая характеристики пылесосов Centek CT-2519, Bosch BGBS2BA1P и Delta LUX DE-3501, я бы рекомендовал Centek CT-2519. Он имеет фильтр тонкой очистки, который эффективно удаляет аллергены и загрязнения из воздуха, а также имеет телескопическую трубу всасывания, которая легко подстраивается под рост пользователя. Кроме того, он имеет регулятор мощности на корпусе, что удобно для пользователей. Емкость пылесборника составляет 4 л, что достаточно для большинства случаев.
#
# Однако, если вам важна производительность и мощность, то Bosch BGBS2BA1P может быть более подходящим вариантом. Он имеет более высокую мощность всасывания и более эффективную систему фильтрации.
#
# Delta LUX DE-3501 также имеет свои преимущества, такие как 5-ступенчатая система фильтрации и циклонная система фильтрации, но он имеет меньшую емкость пылесборника и меньшую мощность всасывания.
#
# В целом, выбор лучшего пылесоса зависит от ваших конкретных потребностей и предпочтений.
# запрос 3: Среди упомянутых тобою пылесосов найди тот, у которого наибольшая длина провода
# Сравнивая характеристики пылесосов, я нашел, что у Bosch BGBS2BA1P длина сетевого шнура составляет 7 м, что является наибольшей среди упомянутых пылесосов.

# %%
# !pip install --upgrade langgraph
# Out:
# Requirement already satisfied: langgraph in /usr/local/lib/python3.11/dist-packages (0.3.18)
# Requirement already satisfied: langchain-core<0.4,>=0.1 in /usr/local/lib/python3.11/dist-packages (from langgraph) (0.3.47)
# Requirement already satisfied: langgraph-checkpoint<3.0.0,>=2.0.10 in /usr/local/lib/python3.11/dist-packages (from langgraph) (2.0.21)
# Requirement already satisfied: langgraph-prebuilt<0.2,>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from langgraph) (0.1.4)
# Requirement already satisfied: langgraph-sdk<0.2.0,>=0.1.42 in /usr/local/lib/python3.11/dist-packages (from langgraph) (0.1.58)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4,>=0.1->langgraph) (0.3.15)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4,>=0.1->langgraph) (9.0.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4,>=0.1->langgraph) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4,>=0.1->langgraph) (6.0.2)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4,>=0.1->langgraph) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4,>=0.1->langgraph) (4.12.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4,>=0.1->langgraph) (2.10.6)
# Requirement already satisfied: msgpack<2.0.0,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from langgraph-checkpoint<3.0.0,>=2.0.10->langgraph) (1.1.0)
# Requirement already satisfied: httpx>=0.25.2 in /usr/local/lib/python3.11/dist-packages (from langgraph-sdk<0.2.0,>=0.1.42->langgraph) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in /usr/local/lib/python3.11/dist-packages (from langgraph-sdk<0.2.0,>=0.1.42->langgraph) (3.10.15)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph) (4.9.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4,>=0.1->langgraph) (3.0.0)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4,>=0.1->langgraph) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4,>=0.1->langgraph) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4,>=0.1->langgraph) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4,>=0.1->langgraph) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4,>=0.1->langgraph) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain-core<0.4,>=0.1->langgraph) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain-core<0.4,>=0.1->langgraph) (2.3.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph) (1.3.1)

# %%
# !pip install --upgrade langchain_community
# Out:
# Collecting langchain_community
#   Downloading langchain_community-0.3.20-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.45 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (0.3.45)
# Collecting langchain<1.0.0,>=0.3.21 (from langchain_community)
#   Downloading langchain-0.3.21-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (2.0.39)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (3.11.14)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (9.0.0)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain_community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain_community)
#   Downloading pydantic_settings-2.8.1-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (0.3.15)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain_community)
#   Downloading httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: numpy<3,>=1.26.2 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (2.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.2.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.18.3)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Downloading marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting langchain-text-splitters<1.0.0,>=0.3.7 (from langchain<1.0.0,>=0.3.21->langchain_community)
#   Downloading langchain_text_splitters-0.3.7-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.11/dist-packages (from langchain<1.0.0,>=0.3.21->langchain_community) (2.10.6)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.45->langchain_community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.45->langchain_community) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.45->langchain_community) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain_community) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain_community) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain_community) (0.23.0)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.4.0->langchain_community)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain_community) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain_community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain_community) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain_community) (2025.1.31)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy<3,>=1.4->langchain_community) (3.1.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_community) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_community) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.45->langchain_community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.21->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.21->langchain_community) (2.27.2)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_community) (1.3.1)
# Downloading langchain_community-0.3.20-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 21.5 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Downloading langchain-0.3.21-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 7.4 MB/s eta 0:00:00
# Downloading pydantic_settings-2.8.1-py3-none-any.whl (30 kB)
# Downloading langchain_text_splitters-0.3.7-py3-none-any.whl (32 kB)
# Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 1.8 MB/s eta 0:00:00
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: python-dotenv, mypy-extensions, marshmallow, httpx-sse, typing-inspect, pydantic-settings, dataclasses-json, langchain-text-splitters, langchain, langchain_community
#   Attempting uninstall: langchain-text-splitters
#     Found existing installation: langchain-text-splitters 0.3.6
#     Uninstalling langchain-text-splitters-0.3.6:
#       Successfully uninstalled langchain-text-splitters-0.3.6
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.3.20
#     Uninstalling langchain-0.3.20:
#       Successfully uninstalled langchain-0.3.20
# Successfully installed dataclasses-json-0.6.7 httpx-sse-0.4.0 langchain-0.3.21 langchain-text-splitters-0.3.7 langchain_community-0.3.20 marshmallow-3.26.1 mypy-extensions-1.0.0 pydantic-settings-2.8.1 python-dotenv-1.0.1 typing-inspect-0.9.0

# %%
# !pip install chromadb
# Out:
# Collecting chromadb
#   Downloading chromadb-0.6.3-py3-none-any.whl.metadata (6.8 kB)
# Collecting build>=1.0.3 (from chromadb)
#   Downloading build-1.2.2.post1-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: pydantic>=1.9 in /usr/local/lib/python3.11/dist-packages (from chromadb) (2.10.6)
# Collecting chroma-hnswlib==0.7.6 (from chromadb)
#   Downloading chroma_hnswlib-0.7.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (252 bytes)
# Collecting fastapi>=0.95.2 (from chromadb)
#   Downloading fastapi-0.115.11-py3-none-any.whl.metadata (27 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading uvicorn-0.34.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: numpy>=1.22.5 in /usr/local/lib/python3.11/dist-packages (from chromadb) (2.0.2)
# Collecting posthog>=2.4.0 (from chromadb)
#   Downloading posthog-3.21.0-py2.py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing_extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from chromadb) (4.12.2)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Downloading onnxruntime-1.21.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from chromadb) (1.31.0)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.31.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb)
#   Downloading opentelemetry_instrumentation_fastapi-0.52b1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from chromadb) (1.31.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /usr/local/lib/python3.11/dist-packages (from chromadb) (0.21.1)
# Collecting pypika>=0.48.9 (from chromadb)
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 4.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.11/dist-packages (from chromadb) (4.67.1)
# Collecting overrides>=7.3.1 (from chromadb)
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.11/dist-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.11/dist-packages (from chromadb) (1.71.0)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Downloading bcrypt-4.3.0-cp39-abi3-manylinux_2_34_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from chromadb) (0.15.2)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Downloading kubernetes-32.0.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.11/dist-packages (from chromadb) (9.0.0)
# Requirement already satisfied: PyYAML>=6.0.0 in /usr/local/lib/python3.11/dist-packages (from chromadb) (6.0.2)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Downloading mmh3-5.1.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (16 kB)
# Requirement already satisfied: orjson>=3.9.12 in /usr/local/lib/python3.11/dist-packages (from chromadb) (3.10.15)
# Requirement already satisfied: httpx>=0.27.0 in /usr/local/lib/python3.11/dist-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from chromadb) (13.9.4)
# Requirement already satisfied: packaging>=19.1 in /usr/local/lib/python3.11/dist-packages (from build>=1.0.3->chromadb) (24.2)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb)
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting starlette<0.47.0,>=0.40.0 (from fastapi>=0.95.2->chromadb)
#   Downloading starlette-0.46.1-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx>=0.27.0->chromadb) (4.9.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx>=0.27.0->chromadb) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.27.0->chromadb) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx>=0.27.0->chromadb) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb) (2.38.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb) (2.32.3)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb) (2.3.0)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb)
#   Downloading durationpy-0.9-py3-none-any.whl.metadata (338 bytes)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.14.1->chromadb) (25.2.10)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.14.1->chromadb) (5.29.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.14.1->chromadb) (1.13.1)
# Requirement already satisfied: deprecated>=1.2.6 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.18)
# Requirement already satisfied: importlib-metadata<8.7.0,>=6.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-api>=1.2.0->chromadb) (8.6.1)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.69.2)
# Collecting opentelemetry-exporter-otlp-proto-common==1.31.1 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.31.1-py3-none-any.whl.metadata (1.9 kB)
# Collecting opentelemetry-proto==1.31.1 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_proto-1.31.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Downloading opentelemetry_sdk-1.31.1-py3-none-any.whl.metadata (1.6 kB)
# Collecting opentelemetry-instrumentation-asgi==0.52b1 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_instrumentation_asgi-0.52b1-py3-none-any.whl.metadata (2.1 kB)
# Collecting opentelemetry-instrumentation==0.52b1 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_instrumentation-0.52b1-py3-none-any.whl.metadata (6.8 kB)
# Collecting opentelemetry-semantic-conventions==0.52b1 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_semantic_conventions-0.52b1-py3-none-any.whl.metadata (2.5 kB)
# Collecting opentelemetry-util-http==0.52b1 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_util_http-0.52b1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-instrumentation==0.52b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.17.2)
# Collecting asgiref~=3.0 (from opentelemetry-instrumentation-asgi==0.52b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading asgiref-3.8.1-py3-none-any.whl.metadata (9.3 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Downloading opentelemetry_api-1.31.1-py3-none-any.whl.metadata (1.6 kB)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb)
#   Downloading monotonic-1.6-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting backoff>=1.10.0 (from posthog>=2.4.0->chromadb)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: distro>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from posthog>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=1.9->chromadb) (2.27.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->chromadb) (2.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.11/dist-packages (from tokenizers>=0.13.2->chromadb) (0.29.3)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer>=0.9.0->chromadb) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading httptools-0.6.4-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Requirement already satisfied: python-dotenv>=0.13 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.1)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading uvloop-0.21.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading watchfiles-1.0.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (14.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.3.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata<8.7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.21.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->kubernetes>=28.1.0->chromadb) (3.4.1)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx>=0.27.0->chromadb) (1.3.1)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Downloading chromadb-0.6.3-py3-none-any.whl (611 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.1/611.1 kB 32.3 MB/s eta 0:00:00
# Downloading chroma_hnswlib-0.7.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 56.2 MB/s eta 0:00:00
# Downloading bcrypt-4.3.0-cp39-abi3-manylinux_2_34_x86_64.whl (284 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.2/284.2 kB 19.8 MB/s eta 0:00:00
# Downloading build-1.2.2.post1-py3-none-any.whl (22 kB)
# Downloading fastapi-0.115.11-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.9/94.9 kB 8.7 MB/s eta 0:00:00
# Downloading kubernetes-32.0.1-py2.py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 72.5 MB/s eta 0:00:00
# Downloading mmh3-5.1.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 9.5 MB/s eta 0:00:00
# Downloading onnxruntime-1.21.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 85.2 MB/s eta 0:00:00
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.31.1-py3-none-any.whl (18 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.31.1-py3-none-any.whl (18 kB)
# Downloading opentelemetry_proto-1.31.1-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.9/55.9 kB 4.4 MB/s eta 0:00:00
# Downloading opentelemetry_instrumentation_fastapi-0.52b1-py3-none-any.whl (12 kB)
# Downloading opentelemetry_instrumentation-0.52b1-py3-none-any.whl (31 kB)
# Downloading opentelemetry_instrumentation_asgi-0.52b1-py3-none-any.whl (16 kB)
# Downloading opentelemetry_semantic_conventions-0.52b1-py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.4/183.4 kB 13.9 MB/s eta 0:00:00
# Downloading opentelemetry_api-1.31.1-py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.2/65.2 kB 4.8 MB/s eta 0:00:00
# Downloading opentelemetry_util_http-0.52b1-py3-none-any.whl (7.3 kB)
# Downloading opentelemetry_sdk-1.31.1-py3-none-any.whl (118 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.9/118.9 kB 8.8 MB/s eta 0:00:00
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading posthog-3.21.0-py2.py3-none-any.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.6/79.6 kB 6.4 MB/s eta 0:00:00
# Downloading uvicorn-0.34.0-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 4.5 MB/s eta 0:00:00
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading durationpy-0.9-py3-none-any.whl (3.5 kB)
# Downloading httptools-0.6.4-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (459 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 459.8/459.8 kB 30.1 MB/s eta 0:00:00
# Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Downloading starlette-0.46.1-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 6.0 MB/s eta 0:00:00
# Downloading uvloop-0.21.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 77.5 MB/s eta 0:00:00
# Downloading watchfiles-1.0.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (452 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 452.6/452.6 kB 27.4 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 2.8 MB/s eta 0:00:00
# Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Downloading asgiref-3.8.1-py3-none-any.whl (23 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 7.0 MB/s eta 0:00:00
# Building wheels for collected packages: pypika
#   Building wheel for pypika (pyproject.toml) ... done
#   Created wheel for pypika: filename=pypika-0.48.9-py2.py3-none-any.whl size=53801 sha256=c8d6765c26967218e8cce7f7bed6700e6301621f290a032f42359f07ada59098
#   Stored in directory: /root/.cache/pip/wheels/a3/01/bd/4c40ceb9d5354160cb186dcc153360f4ab7eb23e2b24daf96d
# Successfully built pypika
# Installing collected packages: pypika, monotonic, durationpy, uvloop, uvicorn, pyproject_hooks, overrides, opentelemetry-util-http, opentelemetry-proto, mmh3, humanfriendly, httptools, chroma-hnswlib, bcrypt, backoff, asgiref, watchfiles, starlette, posthog, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, coloredlogs, build, opentelemetry-semantic-conventions, onnxruntime, kubernetes, fastapi, opentelemetry-sdk, opentelemetry-instrumentation, opentelemetry-instrumentation-asgi, opentelemetry-exporter-otlp-proto-grpc, opentelemetry-instrumentation-fastapi, chromadb
#   Attempting uninstall: opentelemetry-api
#     Found existing installation: opentelemetry-api 1.31.0
#     Uninstalling opentelemetry-api-1.31.0:
#       Successfully uninstalled opentelemetry-api-1.31.0
#   Attempting uninstall: opentelemetry-semantic-conventions
#     Found existing installation: opentelemetry-semantic-conventions 0.52b0
#     Uninstalling opentelemetry-semantic-conventions-0.52b0:
#       Successfully uninstalled opentelemetry-semantic-conventions-0.52b0
#   Attempting uninstall: opentelemetry-sdk
#     Found existing installation: opentelemetry-sdk 1.31.0
#     Uninstalling opentelemetry-sdk-1.31.0:
#       Successfully uninstalled opentelemetry-sdk-1.31.0
# Successfully installed asgiref-3.8.1 backoff-2.2.1 bcrypt-4.3.0 build-1.2.2.post1 chroma-hnswlib-0.7.6 chromadb-0.6.3 coloredlogs-15.0.1 durationpy-0.9 fastapi-0.115.11 httptools-0.6.4 humanfriendly-10.0 kubernetes-32.0.1 mmh3-5.1.0 monotonic-1.6 onnxruntime-1.21.0 opentelemetry-api-1.31.1 opentelemetry-exporter-otlp-proto-common-1.31.1 opentelemetry-exporter-otlp-proto-grpc-1.31.1 opentelemetry-instrumentation-0.52b1 opentelemetry-instrumentation-asgi-0.52b1 opentelemetry-instrumentation-fastapi-0.52b1 opentelemetry-proto-1.31.1 opentelemetry-sdk-1.31.1 opentelemetry-semantic-conventions-0.52b1 opentelemetry-util-http-0.52b1 overrides-7.7.0 posthog-3.21.0 pypika-0.48.9 pyproject_hooks-1.2.0 starlette-0.46.1 uvicorn-0.34.0 uvloop-0.21.0 watchfiles-1.0.4

# %%
# !pip install langchain-groq
# Out:
# Collecting langchain-groq
#   Downloading langchain_groq-0.3.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting langchain-core<1.0.0,>=0.3.47 (from langchain-groq)
#   Downloading langchain_core-0.3.47-py3-none-any.whl.metadata (5.9 kB)
# Collecting groq<1,>=0.4.1 (from langchain-groq)
#   Downloading groq-0.20.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from groq<1,>=0.4.1->langchain-groq) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from groq<1,>=0.4.1->langchain-groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from groq<1,>=0.4.1->langchain-groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from groq<1,>=0.4.1->langchain-groq) (2.10.6)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from groq<1,>=0.4.1->langchain-groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.11/dist-packages (from groq<1,>=0.4.1->langchain-groq) (4.12.2)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.47->langchain-groq) (0.3.15)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.47->langchain-groq) (9.0.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.47->langchain-groq) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.47->langchain-groq) (6.0.2)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.47->langchain-groq) (24.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->groq<1,>=0.4.1->langchain-groq) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.47->langchain-groq) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.47->langchain-groq) (3.10.15)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.47->langchain-groq) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.47->langchain-groq) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.47->langchain-groq) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain-groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain-groq) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.47->langchain-groq) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.47->langchain-groq) (2.3.0)
# Downloading langchain_groq-0.3.1-py3-none-any.whl (15 kB)
# Downloading groq-0.20.0-py3-none-any.whl (124 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.9/124.9 kB 8.4 MB/s eta 0:00:00
# Downloading langchain_core-0.3.47-py3-none-any.whl (417 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.1/417.1 kB 23.1 MB/s eta 0:00:00
# Installing collected packages: groq, langchain-core, langchain-groq
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.45
#     Uninstalling langchain-core-0.3.45:
#       Successfully uninstalled langchain-core-0.3.45
# Successfully installed groq-0.20.0 langchain-core-0.3.47 langchain-groq-0.3.1

# %%
# !pip install --upgrade huggingface_hub transformers
# Out:
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.11/dist-packages (0.29.3)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.49.0)
# Collecting transformers
#   Downloading transformers-4.50.0-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (4.12.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub) (2025.1.31)
# Downloading transformers-4.50.0-py3-none-any.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 23.7 MB/s eta 0:00:00
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.49.0
#     Uninstalling transformers-4.49.0:
#       Successfully uninstalled transformers-4.49.0
# Successfully installed transformers-4.50.0

# %%
# !pip install langchain_community
# Out:
# Requirement already satisfied: langchain_community in /usr/local/lib/python3.11/dist-packages (0.3.20)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.45 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (0.3.47)
# Requirement already satisfied: langchain<1.0.0,>=0.3.21 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (0.3.21)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (2.0.39)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (3.11.14)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (9.0.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (2.8.1)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (0.3.15)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (0.4.0)
# Requirement already satisfied: numpy<3,>=1.26.2 in /usr/local/lib/python3.11/dist-packages (from langchain_community) (2.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.2.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.18.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.11/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.7 in /usr/local/lib/python3.11/dist-packages (from langchain<1.0.0,>=0.3.21->langchain_community) (0.3.7)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.11/dist-packages (from langchain<1.0.0,>=0.3.21->langchain_community) (2.10.6)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.45->langchain_community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.45->langchain_community) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.45->langchain_community) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain_community) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain_community) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain_community) (0.23.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain_community) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain_community) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain_community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain_community) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain_community) (2025.1.31)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy<3,>=1.4->langchain_community) (3.1.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_community) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_community) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.45->langchain_community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.21->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.21->langchain_community) (2.27.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_community) (1.3.1)

# %%
# !pip install --upgrade langchain_groq
# Out:
# Requirement already satisfied: langchain_groq in /usr/local/lib/python3.11/dist-packages (0.3.1)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.47 in /usr/local/lib/python3.11/dist-packages (from langchain_groq) (0.3.47)
# Requirement already satisfied: groq<1,>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from langchain_groq) (0.20.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from groq<1,>=0.4.1->langchain_groq) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from groq<1,>=0.4.1->langchain_groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from groq<1,>=0.4.1->langchain_groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from groq<1,>=0.4.1->langchain_groq) (2.10.6)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from groq<1,>=0.4.1->langchain_groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.11/dist-packages (from groq<1,>=0.4.1->langchain_groq) (4.12.2)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.47->langchain_groq) (0.3.15)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.47->langchain_groq) (9.0.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.47->langchain_groq) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.47->langchain_groq) (6.0.2)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.47->langchain_groq) (24.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->groq<1,>=0.4.1->langchain_groq) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain_groq) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain_groq) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain_groq) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.47->langchain_groq) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.47->langchain_groq) (3.10.15)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.47->langchain_groq) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.47->langchain_groq) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.47->langchain_groq) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain_groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain_groq) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.47->langchain_groq) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.47->langchain_groq) (2.3.0)

# %%
def generate_answer(row):

    filter = {"filename": {"$in": ["Война и мир 1.txt", "Война и мир 2.txt"]}}
    res = vectorstore.similarity_search(q,filter=filter,k=1)
    context.append(res[0].page_content)
  vectorstore.similarity_search(question,filter=filter,k=1)[0].page_content)

# %%
for var in globals().copy():
    if var.startswith("__"):
        continue
    del globals()[var]

for var in locals().copy():
    if var.startswith("__"):
        continue
    del locals()[var]

# %%
# !pip install langchain_gigachat
# Out:
# Collecting langchain_gigachat
#   Downloading langchain_gigachat-0.3.8-py3-none-any.whl.metadata (2.9 kB)
# Collecting gigachat<0.2.0,>=0.1.39 (from langchain_gigachat)
#   Downloading gigachat-0.1.39.post1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: langchain-core<0.4,>=0.3 in /usr/local/lib/python3.11/dist-packages (from langchain_gigachat) (0.3.47)
# Collecting types-requests<3.0,>=2.32 (from langchain_gigachat)
#   Downloading types_requests-2.32.0.20250306-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: httpx<1 in /usr/local/lib/python3.11/dist-packages (from gigachat<0.2.0,>=0.1.39->langchain_gigachat) (0.28.1)
# Requirement already satisfied: pydantic>=1 in /usr/local/lib/python3.11/dist-packages (from gigachat<0.2.0,>=0.1.39->langchain_gigachat) (2.10.6)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4,>=0.3->langchain_gigachat) (0.3.15)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4,>=0.3->langchain_gigachat) (9.0.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4,>=0.3->langchain_gigachat) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4,>=0.3->langchain_gigachat) (6.0.2)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4,>=0.3->langchain_gigachat) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4,>=0.3->langchain_gigachat) (4.12.2)
# Requirement already satisfied: urllib3>=2 in /usr/local/lib/python3.11/dist-packages (from types-requests<3.0,>=2.32->langchain_gigachat) (2.3.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<1->gigachat<0.2.0,>=0.1.39->langchain_gigachat) (4.9.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1->gigachat<0.2.0,>=0.1.39->langchain_gigachat) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1->gigachat<0.2.0,>=0.1.39->langchain_gigachat) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx<1->gigachat<0.2.0,>=0.1.39->langchain_gigachat) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1->gigachat<0.2.0,>=0.1.39->langchain_gigachat) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4,>=0.3->langchain_gigachat) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4,>=0.3->langchain_gigachat) (3.10.15)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4,>=0.3->langchain_gigachat) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4,>=0.3->langchain_gigachat) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4,>=0.3->langchain_gigachat) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=1->gigachat<0.2.0,>=0.1.39->langchain_gigachat) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=1->gigachat<0.2.0,>=0.1.39->langchain_gigachat) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain-core<0.4,>=0.3->langchain_gigachat) (3.4.1)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx<1->gigachat<0.2.0,>=0.1.39->langchain_gigachat) (1.3.1)
# Downloading langchain_gigachat-0.3.8-py3-none-any.whl (26 kB)
# Downloading gigachat-0.1.39.post1-py3-none-any.whl (67 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 2.8 MB/s eta 0:00:00
# Downloading types_requests-2.32.0.20250306-py3-none-any.whl (20 kB)
# Installing collected packages: types-requests, gigachat, langchain_gigachat
# Successfully installed gigachat-0.1.39.post1 langchain_gigachat-0.3.8 types-requests-2.32.0.20250306

# %%
# !pip install langgraph
# Out:
# Collecting langgraph
#   Downloading langgraph-0.3.18-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: langchain-core<0.4,>=0.1 in /usr/local/lib/python3.11/dist-packages (from langgraph) (0.3.47)
# Collecting langgraph-checkpoint<3.0.0,>=2.0.10 (from langgraph)
#   Downloading langgraph_checkpoint-2.0.21-py3-none-any.whl.metadata (4.6 kB)
# Collecting langgraph-prebuilt<0.2,>=0.1.1 (from langgraph)
#   Downloading langgraph_prebuilt-0.1.4-py3-none-any.whl.metadata (5.0 kB)
# Collecting langgraph-sdk<0.2.0,>=0.1.42 (from langgraph)
#   Downloading langgraph_sdk-0.1.58-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4,>=0.1->langgraph) (0.3.15)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4,>=0.1->langgraph) (9.0.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4,>=0.1->langgraph) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4,>=0.1->langgraph) (6.0.2)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4,>=0.1->langgraph) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4,>=0.1->langgraph) (4.12.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4,>=0.1->langgraph) (2.10.6)
# Requirement already satisfied: msgpack<2.0.0,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from langgraph-checkpoint<3.0.0,>=2.0.10->langgraph) (1.1.0)
# Requirement already satisfied: httpx>=0.25.2 in /usr/local/lib/python3.11/dist-packages (from langgraph-sdk<0.2.0,>=0.1.42->langgraph) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in /usr/local/lib/python3.11/dist-packages (from langgraph-sdk<0.2.0,>=0.1.42->langgraph) (3.10.15)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph) (4.9.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4,>=0.1->langgraph) (3.0.0)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4,>=0.1->langgraph) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4,>=0.1->langgraph) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4,>=0.1->langgraph) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4,>=0.1->langgraph) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4,>=0.1->langgraph) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain-core<0.4,>=0.1->langgraph) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain-core<0.4,>=0.1->langgraph) (2.3.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph) (1.3.1)
# Downloading langgraph-0.3.18-py3-none-any.whl (136 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 136.5/136.5 kB 5.7 MB/s eta 0:00:00
# Downloading langgraph_checkpoint-2.0.21-py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 kB 2.8 MB/s eta 0:00:00
# Downloading langgraph_prebuilt-0.1.4-py3-none-any.whl (24 kB)
# Downloading langgraph_sdk-0.1.58-py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.5/46.5 kB 3.2 MB/s eta 0:00:00
# Installing collected packages: langgraph-sdk, langgraph-checkpoint, langgraph-prebuilt, langgraph
# Successfully installed langgraph-0.3.18 langgraph-checkpoint-2.0.21 langgraph-prebuilt-0.1.4 langgraph-sdk-0.1.58
